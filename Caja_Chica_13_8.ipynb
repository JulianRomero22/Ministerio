# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Replace '/content/drive/My Drive/path/to/your/file/' with the actual path to your files
devengado_2024_df = pd.read_excel('/content/drive/My Drive/Devengado 2024.xlsx')
devengado_2025_df = pd.read_excel('/content/drive/My Drive/REPORTE DEVENGADO 2025 - 05-08.xlsx', )

# Read the uploaded files
# devengado_2024_df = pd.read_excel(uploaded['Devengado 2024.xlsx'])
# devengado_2025_df = pd.read_excel(uploaded['Devengado 2025.xlsx'])


print("First 5 rows of Devengado 2024:")
display(devengado_2024_df.head())

print("\nFirst 5 rows of Devengado 2025:")
display(devengado_2025_df.head())
# Out:
# First 5 rows of Devengado 2024:
#         Fecha   Referencia                  Tipo Doc Respaldo   \
# 0   09/01/2024  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS
# 1   09/01/2024  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS
# 2   09/01/2024  2024/000003                            FACTURA
# 3   09/01/2024  2024/000003                            FACTURA
# 4   09/01/2024  2024/000004                            FACTURA
#
#   Letra Comprobante  N° Doc Respaldo  Asociada  Asociada a Comp. N°   \
# 0                  B    0400-49501051       NaN                  NaN
# 1                  B    0400-49501051       NaN                  NaN
# 2                  B   00004-00007708       NaN                  NaN
# 3                  B   00004-00007708       NaN                  NaN
# 4                  B   00003-00005812       NaN                  NaN
#
#    Tipo Contratacion   Detalle Contratacion        Expediente   ...  \
# 0                 NaN                    NaN  0425-505607/2024  ...
# 1                 NaN                    NaN  0425-505607/2024  ...
# 2                 NaN                    NaN  0425-501643/2024  ...
# 3                 NaN                    NaN  0425-501643/2024  ...
# 4                 NaN                    NaN  0425-501647/2024  ...
#
#   Codigo Autorizacion  Fecha Vto CAI  N° Lote  MesAnio   \
# 0         3.452901e+13     07/01/2024      NaN      NaN
# 1         3.452901e+13     07/01/2024      NaN      NaN
# 2         7.401983e+13     14/01/2024      NaN      NaN
# 3         7.401983e+13     14/01/2024      NaN      NaN
# 4         7.401272e+13     13/01/2024      NaN      NaN
#
#                                         Familia Bien  Nro Compr Web  \
# 0  9814000000-DE DEUDAS CON PROVEEDORES Y CONTRAT...             --
# 1                      8310000000-SERVICIOS PUBLICOS             --
# 2                5113000000-MEDICAMENTOS HEMATOLICOS             --
# 3  5114000000-MEDICAMENTOS PARA EL SISTEMA NERVIO...             --
# 4  4222000000-PRODUCTOS PARA ADMINISTRACION INTRA...             --
#
#   Validado Afip Fecha Validad Abierta  id_devengado
# 0        VÁLIDO    08/01/2024      NO       9120561
# 1        VÁLIDO    08/01/2024      NO       9120561
# 2        VÁLIDO    04/01/2024      NO       9121676
# 3        VÁLIDO    04/01/2024      NO       9121676
# 4        VÁLIDO    03/01/2024      NO       9121698
#
# [5 rows x 71 columns]
# First 5 rows of Devengado 2025:
#         Fecha   Referencia  Tipo Doc Respaldo  Letra Comprobante   \
# 0   03/01/2025  2025/000002     NOTA - INFORME                  B
# 1   03/01/2025  2025/000003            FACTURA                  B
# 2   03/01/2025  2025/000004            FACTURA                  B
# 3   03/01/2025  2025/000005            FACTURA                  B
# 4   03/01/2025  2025/000006            FACTURA                  C
#
#   N° Doc Respaldo  Asociada  Asociada a Comp. N°   Tipo Contratacion   \
# 0             1258       NaN                  NaN                 NaN
# 1   00009-00151984       NaN                  NaN                 NaN
# 2   13537-00322187       NaN                  NaN                 NaN
# 3   00010-63344086       NaN                  NaN                 NaN
# 4   00001-00000285       NaN                  NaN                 NaN
#
#    Detalle Contratacion  Expediente   ... Codigo Autorizacion  Fecha Vto CAI   \
# 0                    NaN         NaN  ...                  NaN            NaN
# 1                    NaN         NaN  ...                  NaN            NaN
# 2                    NaN         NaN  ...                  NaN            NaN
# 3                    NaN         NaN  ...                  NaN            NaN
# 4                    NaN         NaN  ...         7.501730e+13     12/01/2025
#
#   N° Lote  MesAnio                                        Familia Bien  \
# 0      NaN      NaN    7811000000-SERVICIOS DE TRANSPORTE DE PASAJEROS
# 1      NaN      NaN                  5018000000-PRODUCTOS DE PANADERIA
# 2      NaN      NaN  2611000000-BATERIAS, GENERADORES Y TRANSMISION...
# 3      NaN      NaN                      8310000000-SERVICIOS PUBLICOS
# 4      NaN      NaN           7812000000-MANEJO Y EMBALAJE DE MATERIAL
#
#    Nro Compr Web Validado Afip Fecha Validad Abierta  id_devengado
# 0             --            --           NaN      NO       9655546
# 1             --            --           NaN      NO       9655564
# 2             --            --           NaN      NO       9655588
# 3             --            --           NaN      NO       9655613
# 4             --        VÁLIDO    02/01/2025      NO       9656061
#
# [5 rows x 71 columns]

# %%
print("Information about Devengado 2024 DataFrame:")
devengado_2024_df.info()

print("\nInformation about Devengado 2025 DataFrame:")
devengado_2025_df.info()
# Out:
# Information about Devengado 2024 DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267516 entries, 0 to 267515
# Data columns (total 71 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Fecha                  267516 non-null  object
#  1   Referencia             267516 non-null  object
#  2   Tipo Doc Respaldo      267516 non-null  object
#  3   Letra Comprobante      267516 non-null  object
#  4   N° Doc Respaldo        267516 non-null  object
#  5   Asociada               2291 non-null    object
#  6   Asociada a Comp. N°    2291 non-null    object
#  7   Tipo Contratacion      0 non-null       float64
#  8   Detalle Contratacion   0 non-null       float64
#  9   Expediente             168518 non-null  object
#  10  Estado                 267516 non-null  object
#  11  Proveedor              267516 non-null  object
#  12  Grupo                  267516 non-null  object
#  13  Programa               267516 non-null  object
#  14  Descripcion del Bien   267516 non-null  object
#  15  N° Objeto Gasto        267516 non-null  int64
#  16  Centro Costo           267516 non-null  object
#  17  Obra                   267516 non-null  object
#  18  Ofic Solicitante       267516 non-null  object
#  19  Cantidad               267516 non-null  float64
#  20  Importe Unitario       267516 non-null  float64
#  21  Importe por Item       267516 non-null  float64
#  22  Monto Total Dev        267516 non-null  float64
#  23  N° Compromiso          31415 non-null   object
#  24  Estado Compromiso      31415 non-null   object
#  25  N° Egreso              234127 non-null  object
#  26  N° DUEE                181986 non-null  float64
#  27  Cargo                  174620 non-null  object
#  28  Expediente Interv      181986 non-null  object
#  29  N° Intervencion        181986 non-null  float64
#  30  Est. Intervencion      181986 non-null  object
#  31  N° Ep                  219982 non-null  object
#  32  Rendicion FP           79045 non-null   float64
#  33  Letra Fondo            71585 non-null   object
#  34  Observacion            267516 non-null  object
#  35  Fecha Comp             267516 non-null  object
#  36  Mes Comp               267516 non-null  object
#  37  Fec Conformacion       267516 non-null  object
#  38  Fecha Vto Doc          69678 non-null   object
#  39  Rendicion CCH          79045 non-null   float64
#  40  Letra CCH              71585 non-null   object
#  41  Fecha Egreso           234127 non-null  object
#  42  N° Anticipo            19540 non-null   object
#  43  Fecha Cierre Ant       19540 non-null   object
#  44  Fec Ordenado Pagar     260794 non-null  object
#  45  Fecha Pago             217030 non-null  object
#  46  Fecha Anticipo         19540 non-null   object
#  47  F. Ejec Devengado      267516 non-null  object
#  48  Fecha Visado           174620 non-null  object
#  49  Ordenado a Pagar       267516 non-null  object
#  50  CUIT                   267508 non-null  float64
#  51  Devengados Asociados   2183 non-null    object
#  52  N° Visacion            174620 non-null  float64
#  53  Dominio                627 non-null     object
#  54  Estado Item            267516 non-null  object
#  55  Tipo Certificado       51 non-null      object
#  56  N° Certificado         51 non-null      float64
#  57  Mes Certificado        52 non-null      float64
#  58  Fecha Certificado      51 non-null      object
#  59  Certif. Fiscal         190623 non-null  object
#  60  Fecha Anulado          0 non-null       float64
#  61  Codigo Autorizacion    207601 non-null  float64
#  62  Fecha Vto CAI          207455 non-null  object
#  63  N° Lote                5058 non-null    object
#  64  MesAnio                1340 non-null    object
#  65  Familia Bien           267516 non-null  object
#  66  Nro Compr Web          267516 non-null  object
#  67  Validado Afip          267516 non-null  object
#  68  Fecha Validad          210104 non-null  object
#  69  Abierta                267516 non-null  object
#  70  id_devengado           267516 non-null  int64
# dtypes: float64(16), int64(2), object(53)
# memory usage: 144.9+ MB
#
# Information about Devengado 2025 DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155821 entries, 0 to 155820
# Data columns (total 71 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Fecha                  155821 non-null  object
#  1   Referencia             155821 non-null  object
#  2   Tipo Doc Respaldo      155821 non-null  object
#  3   Letra Comprobante      155821 non-null  object
#  4   N° Doc Respaldo        155821 non-null  object
#  5   Asociada               1195 non-null    object
#  6   Asociada a Comp. N°    1195 non-null    object
#  7   Tipo Contratacion      0 non-null       float64
#  8   Detalle Contratacion   0 non-null       float64
#  9   Expediente             98883 non-null   object
#  10  Estado                 155821 non-null  object
#  11  Proveedor              155821 non-null  object
#  12  Grupo                  155329 non-null  object
#  13  Programa               155821 non-null  object
#  14  Descripcion del Bien   155821 non-null  object
#  15  N° Objeto Gasto        155821 non-null  int64
#  16  Centro Costo           155821 non-null  object
#  17  Obra                   155821 non-null  object
#  18  Ofic Solicitante       155821 non-null  object
#  19  Cantidad               155821 non-null  float64
#  20  Importe Unitario       155821 non-null  float64
#  21  Importe por Item       155821 non-null  float64
#  22  Monto Total Dev        155819 non-null  float64
#  23  N° Compromiso          17697 non-null   object
#  24  Estado Compromiso      17697 non-null   object
#  25  N° Egreso              117120 non-null  object
#  26  N° DUEE                99835 non-null   float64
#  27  Cargo                  84035 non-null   object
#  28  Expediente Interv      99835 non-null   object
#  29  N° Intervencion        99835 non-null   float64
#  30  Est. Intervencion      99835 non-null   object
#  31  N° Ep                  110552 non-null  object
#  32  Rendicion FP           40360 non-null   float64
#  33  Letra Fondo            40985 non-null   object
#  34  Observacion            155821 non-null  object
#  35  Fecha Comp             155821 non-null  object
#  36  Mes Comp               155821 non-null  object
#  37  Fec Conformacion       155821 non-null  object
#  38  Fecha Vto Doc          32117 non-null   object
#  39  Rendicion CCH          40360 non-null   float64
#  40  Letra CCH              40985 non-null   float64
#  41  Fecha Egreso           84035 non-null   object
#  42  N° Anticipo            9750 non-null    object
#  43  Fecha Cierre Ant       9656 non-null    object
#  44  Fec Ordenado Pagar     141148 non-null  object
#  45  Fecha Pago             109645 non-null  object
#  46  Fecha Anticipo         9750 non-null    object
#  47  F. Ejec Devengado      155821 non-null  object
#  48  Fecha Visado           84036 non-null   object
#  49  Ordenado a Pagar       155821 non-null  object
#  50  CUIT                   155819 non-null  float64
#  51  Devengados Asociados   1137 non-null    object
#  52  N° Visacion            84036 non-null   float64
#  53  Dominio                42 non-null      object
#  54  Estado Item            155821 non-null  object
#  55  Tipo Certificado       19 non-null      object
#  56  N° Certificado         19 non-null      float64
#  57  Mes Certificado        19 non-null      float64
#  58  Fecha Certificado      19 non-null      object
#  59  Certif. Fiscal         114424 non-null  object
#  60  Fecha Anulado          0 non-null       float64
#  61  Codigo Autorizacion    123777 non-null  float64
#  62  Fecha Vto CAI          123763 non-null  object
#  63  N° Lote                3237 non-null    object
#  64  MesAnio                301 non-null     object
#  65  Familia Bien           155821 non-null  object
#  66  Nro Compr Web          155821 non-null  object
#  67  Validado Afip          155821 non-null  object
#  68  Fecha Validad          125053 non-null  object
#  69  Abierta                155821 non-null  object
#  70  id_devengado           155821 non-null  int64
# dtypes: float64(17), int64(2), object(52)
# memory usage: 84.4+ MB

# %%
# Homogeneizamos columnas
def homogenize_columns(df):
    cols = df.columns
    new_cols = []
    for col in cols:
        new_col = col.lower()
        new_col = new_col.replace(' ', '_')
        new_cols.append(new_col)
    df.columns = new_cols
    return df

# Para ambos df
devengado_2024_df = homogenize_columns(devengado_2024_df)
devengado_2025_df = homogenize_columns(devengado_2025_df)

print("Homogenized columns for devengado_2024_df:")
display(devengado_2024_df.columns)

print("\nHomogenized columns for devengado_2025_df:")
display(devengado_2025_df.columns)
# Out:
# Homogenized columns for devengado_2024_df:
# Index(['fecha_', 'referencia_', 'tipo_doc_respaldo_', 'letra_comprobante_',
#        'n°_doc_respaldo_', 'asociada_', 'asociada_a_comp._n°_',
#        'tipo_contratacion_', 'detalle_contratacion_', 'expediente_', 'estado_',
#        'proveedor_', 'grupo_', 'programa_', 'descripcion_del_bien_',
#        'n°_objeto_gasto_', 'centro_costo_', 'obra_', 'ofic_solicitante_',
#        'cantidad_', 'importe_unitario_', 'importe_por_item_',
#        'monto_total_dev_', 'n°_compromiso_', 'estado_compromiso_',
#        'n°_egreso_', 'n°_duee_', 'cargo_', 'expediente_interv_',
#        'n°_intervencion', 'est._intervencion', 'n°_ep_', 'rendicion_fp_',
#        'letra_fondo_', 'observacion_', 'fecha_comp_', 'mes_comp_',
#        'fec_conformacion_', 'fecha_vto_doc_', 'rendicion_cch_', 'letra_cch_',
#        'fecha_egreso_', 'n°_anticipo_', 'fecha_cierre_ant_',
#        'fec_ordenado_pagar_', 'fecha_pago_', 'fecha_anticipo_',
#        'f._ejec_devengado_', 'fecha_visado_', 'ordenado_a_pagar_', 'cuit_',
#        'devengados_asociados_', 'n°_visacion_', 'dominio_', 'estado_item_',
#        'tipo_certificado_', 'n°_certificado_', 'mes_certificado_',
#        'fecha_certificado_', 'certif._fiscal_', 'fecha_anulado_',
#        'codigo_autorizacion_', 'fecha_vto_cai_', 'n°_lote_', 'mesanio_',
#        'familia_bien', 'nro_compr_web', 'validado_afip', 'fecha_validad',
#        'abierta', 'id_devengado'],
#       dtype='object')
# Homogenized columns for devengado_2025_df:
# Index(['fecha_', 'referencia_', 'tipo_doc_respaldo_', 'letra_comprobante_',
#        'n°_doc_respaldo_', 'asociada_', 'asociada_a_comp._n°_',
#        'tipo_contratacion_', 'detalle_contratacion_', 'expediente_', 'estado_',
#        'proveedor_', 'grupo_', 'programa_', 'descripcion_del_bien_',
#        'n°_objeto_gasto_', 'centro_costo_', 'obra_', 'ofic_solicitante_',
#        'cantidad_', 'importe_unitario_', 'importe_por_item_',
#        'monto_total_dev_', 'n°_compromiso_', 'estado_compromiso_',
#        'n°_egreso_', 'n°_duee_', 'cargo_', 'expediente_interv_',
#        'n°_intervencion', 'est._intervencion', 'n°_ep_', 'rendicion_fp_',
#        'letra_fondo_', 'observacion_', 'fecha_comp_', 'mes_comp_',
#        'fec_conformacion_', 'fecha_vto_doc_', 'rendicion_cch_', 'letra_cch_',
#        'fecha_egreso_', 'n°_anticipo_', 'fecha_cierre_ant_',
#        'fec_ordenado_pagar_', 'fecha_pago_', 'fecha_anticipo_',
#        'f._ejec_devengado_', 'fecha_visado_', 'ordenado_a_pagar_', 'cuit_',
#        'devengados_asociados_', 'n°_visacion_', 'dominio_', 'estado_item_',
#        'tipo_certificado_', 'n°_certificado_', 'mes_certificado_',
#        'fecha_certificado_', 'certif._fiscal_', 'fecha_anulado_',
#        'codigo_autorizacion_', 'fecha_vto_cai_', 'n°_lote_', 'mesanio_',
#        'familia_bien', 'nro_compr_web', 'validado_afip', 'fecha_validad',
#        'abierta', 'id_devengado'],
#       dtype='object')

# %%
columns_to_numeric_2024 = [
    'cantidad_',
    'importe_unitario_',
    'importe_por_item_',
]

# Define the list of columns to convert to numeric for devengado_2025_df
columns_to_numeric_2025 = [
    'cantidad_',
    'importe_unitario_',
    'importe_por_item_',
]

for col in columns_to_numeric_2024:
    if col in devengado_2024_df.columns:
        devengado_2024_df[col] = pd.to_numeric(devengado_2024_df[col], errors='coerce')
        print(f"Converted '{col}' to numeric in devengado_2024_df.")
    else:
        print(f"Column '{col}' not found in devengado_2024_df.")

for col in columns_to_numeric_2025:
    if col in devengado_2025_df.columns:
        devengado_2025_df[col] = pd.to_numeric(devengado_2025_df[col], errors='coerce')
        print(f"Converted '{col}' to numeric in devengado_2025_df.")
    else:
        print(f"Column '{col}' not found in devengado_2025_df.")


print("\nData types after converting columns to numeric:")
print("Devengado 2024:")
display(devengado_2024_df[columns_to_numeric_2024].dtypes)

print("\nDevengado 2025:")
display(devengado_2025_df[columns_to_numeric_2025].dtypes)
# Out:
# Converted 'cantidad_' to numeric in devengado_2024_df.
# Converted 'importe_unitario_' to numeric in devengado_2024_df.
# Converted 'importe_por_item_' to numeric in devengado_2024_df.
# Converted 'cantidad_' to numeric in devengado_2025_df.
# Converted 'importe_unitario_' to numeric in devengado_2025_df.
# Converted 'importe_por_item_' to numeric in devengado_2025_df.
#
# Data types after converting columns to numeric:
# Devengado 2024:
# cantidad_            float64
# importe_unitario_    float64
# importe_por_item_    float64
# dtype: object
# Devengado 2025:
# cantidad_            float64
# importe_unitario_    float64
# importe_por_item_    float64
# dtype: object

# %%
columns_to_keep_homogenized = [
    'tipo_doc_respaldo_',
    'n°_doc_respaldo_',
    'expediente_',
    'estado_',
    'grupo_',
    'descripcion_del_bien_',
    'cantidad_',
    'importe_unitario_',
    'importe_por_item_',
    'fecha_comp_',
    'mes_comp_',
    'estado_item_',
    'n°_objeto_gasto_',
    'ofic_solicitante_',
    'programa_',
    'estado_compromiso_',
    'referencia_',
    'letra_cch_',
    'letra_fondo_'
]

# Drop columns from devengado_2024_df
columns_to_drop_2024 = [col for col in devengado_2024_df.columns if col not in columns_to_keep_homogenized]
devengado_2024_df = devengado_2024_df.drop(columns=columns_to_drop_2024)

# Drop columns from devengado_2025_df
columns_to_drop_2025 = [col for col in devengado_2025_df.columns if col not in columns_to_keep_homogenized]
devengado_2025_df = devengado_2025_df.drop(columns=columns_to_drop_2025)

print("Columns remaining in devengado_2024_df after dropping columns:")
display(devengado_2024_df.columns)

print("\nColumns remaining in devengado_2025_df after dropping columns:")
display(devengado_2025_df.columns)
# Out:
# Columns remaining in devengado_2024_df after dropping columns:
# Index(['referencia_', 'tipo_doc_respaldo_', 'n°_doc_respaldo_', 'expediente_',
#        'estado_', 'grupo_', 'programa_', 'descripcion_del_bien_',
#        'n°_objeto_gasto_', 'ofic_solicitante_', 'cantidad_',
#        'importe_unitario_', 'importe_por_item_', 'estado_compromiso_',
#        'letra_fondo_', 'fecha_comp_', 'mes_comp_', 'letra_cch_',
#        'estado_item_'],
#       dtype='object')
# Columns remaining in devengado_2025_df after dropping columns:
# Index(['referencia_', 'tipo_doc_respaldo_', 'n°_doc_respaldo_', 'expediente_',
#        'estado_', 'grupo_', 'programa_', 'descripcion_del_bien_',
#        'n°_objeto_gasto_', 'ofic_solicitante_', 'cantidad_',
#        'importe_unitario_', 'importe_por_item_', 'estado_compromiso_',
#        'letra_fondo_', 'fecha_comp_', 'mes_comp_', 'letra_cch_',
#        'estado_item_'],
#       dtype='object')

# %%
# Concatenate the two dataframes
devengado_combined_df = pd.concat([devengado_2024_df, devengado_2025_df], ignore_index=True)

print("First 5 rows of the combined dataframe:")
display(devengado_combined_df.head())

print("\nLast 5 rows of the combined dataframe:")
display(devengado_combined_df.tail())

print("\nInformation about the combined dataframe:")
devengado_combined_df.info()
# Out:
# First 5 rows of the combined dataframe:
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 1  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 2  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 3  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 4  0425-501647/2024  PAGADO  Rentas   Generales   457-003
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#                ofic_solicitante_  cantidad_  importe_unitario_  \
# 0  DR. EMILIO VIDAL ABAL (OLIVA)        1.0          532205.04
# 1  DR. EMILIO VIDAL ABAL (OLIVA)        1.0          303451.21
# 2                         RAWSON      150.0             340.00
# 3                         RAWSON      390.0              92.00
# 4                         RAWSON        4.0          550046.64
#
#    importe_por_item_ estado_compromiso_ letra_fondo_  fecha_comp_   mes_comp_  \
# 0          532205.04                NaN          NaN   04/01/2024  ENERO
# 1          303451.21                NaN          NaN   04/01/2024  ENERO
# 2           51000.00                NaN          NaN   04/01/2024  ENERO
# 3           35880.00                NaN          NaN   04/01/2024  ENERO
# 4         2200186.56                NaN          NaN   03/01/2024  ENERO
#
#   letra_cch_ estado_item_
# 0        NaN     GENERADO
# 1        NaN     GENERADO
# 2        NaN     GENERADO
# 3        NaN     GENERADO
# 4        NaN     GENERADO
# Last 5 rows of the combined dataframe:
#         referencia_ tipo_doc_respaldo_ n°_doc_respaldo_       expediente_  \
# 423332  2025/079133            FACTURA   00001-00000044  0425-590113/2025
# 423333  2025/079134            FACTURA   00001-00000016   0425-59114/2025
# 423334  2025/079135            FACTURA   00001-00000005  0425-589459/2025
# 423335  2025/079136            FACTURA   00003-00001980  0425-590170/2025
# 423336  2025/079137            FACTURA   00002-00008037  0425-588648/2025
#
#          estado_              grupo_ programa_  \
# 423332  GENERADO  Rentas   Generales   458-006
# 423333  GENERADO  Rentas   Generales   458-006
# 423334  GENERADO  Rentas   Generales   457-008
# 423335  GENERADO  Rentas   Generales   468-000
# 423336  GENERADO  Rentas   Generales   458-028
#
#                  descripcion_del_bien_  n°_objeto_gasto_  \
# 423332  SERVICIOS MEDICOS Y SANITARIOS           3050200
# 423333  SERVICIOS MEDICOS Y SANITARIOS           3050200
# 423334  SERVICIOS MEDICOS Y SANITARIOS           3050200
# 423335                PLACA PROTESICAS           2060500
# 423336                  GLUTARALDEHIDO           2060200
#
#                            ofic_solicitante_  cantidad_  importe_unitario_  \
# 423332           H. VILLA DOLORES SIN OC/OCD        1.0         1382188.50
# 423333           H. VILLA DOLORES SIN OC/OCD        1.0         1382188.50
# 423334                 PEDIÁTRICO SIN OC/OCD        1.0         1231032.00
# 423335  ASISTENCIA SANITARIA - ACCIÓN SOCIAL        1.0               0.01
# 423336                          H. LA CALERA        2.0           29784.15
#
#         importe_por_item_ estado_compromiso_ letra_fondo_  fecha_comp_  \
# 423332         1382188.50                NaN          NaN   01/08/2025
# 423333         1382188.50                NaN          NaN   01/08/2025
# 423334         1231032.00                NaN          NaN   01/08/2025
# 423335               0.01                NaN          NaN   21/05/2025
# 423336           59568.30                NaN          NaN   21/07/2025
#
#          mes_comp_ letra_cch_ estado_item_
# 423332  AGOSTO            NaN     GENERADO
# 423333  AGOSTO            NaN     GENERADO
# 423334  AGOSTO            NaN     GENERADO
# 423335  MAYO              NaN     GENERADO
# 423336  JULIO             NaN     GENERADO
# Information about the combined dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423337 entries, 0 to 423336
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   referencia_            423337 non-null  object
#  1   tipo_doc_respaldo_     423337 non-null  object
#  2   n°_doc_respaldo_       423337 non-null  object
#  3   expediente_            267401 non-null  object
#  4   estado_                423337 non-null  object
#  5   grupo_                 422845 non-null  object
#  6   programa_              423337 non-null  object
#  7   descripcion_del_bien_  423337 non-null  object
#  8   n°_objeto_gasto_       423337 non-null  int64
#  9   ofic_solicitante_      423337 non-null  object
#  10  cantidad_              423337 non-null  float64
#  11  importe_unitario_      423337 non-null  float64
#  12  importe_por_item_      423337 non-null  float64
#  13  estado_compromiso_     49112 non-null   object
#  14  letra_fondo_           112570 non-null  object
#  15  fecha_comp_            423337 non-null  object
#  16  mes_comp_              423337 non-null  object
#  17  letra_cch_             112570 non-null  object
#  18  estado_item_           423337 non-null  object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 61.4+ MB

# %%
# Cargamos los IPC a precios base

datos2= {'Fecha': ['01-24', '02-24', '03-24', '04-24', '05-24', '06-24', '07-24', '08-24', '09-24', '10-24', '11-24', '12-24', '01-25', '02-25', '03-25', '04-25', '05-25', '06-25'], 'ipc':[2.0455, 1.8045, 1.6255, 1.5229, 1.4631, 1.4109, 1.3520, 1.2910, 1.2455, 1.2183, 1.1780, 1.1383, 1.1134, 1.0741, 1.0452, 1.0199, 1.0000, 0.9786]}
ipc_gral=pd.DataFrame(datos2)
ipc_gral['Fecha'] = pd.to_datetime('20' + ipc_gral['Fecha'].str[-2:] + '-' + ipc_gral['Fecha'].str[:2] + '-01')
print(ipc_gral)

datos3= {'Fecha': ['01-24', '02-24', '03-24', '04-24', '05-24', '06-24', '07-24', '08-24', '09-24', '10-24', '11-24', '12-24', '01-25', '02-25', '03-25', '04-25', '05-25', '06-25'], 'Medicamentos': [1.7269, 1.6189, 1.3671, 1.3420, 1.3081, 1.2635, 1.2173, 1.1874, 1.1577, 1.1361, 1.0848, 1.0861, 1.0751, 1.0543, 1.0390, 1.0271, 1.00, 0.9861], 'Descartables': [1.3598, 1.2347, 1.1802, 1.1228, 1.0692, 1.0574, 1.0659, 1.0470, 1.0308, 1.0239, 1.0408, 1.0412, 1.0414, 1.0591, 1.0431, 1.0178, 1.00, 0.9807 ]}
ipc_may25= pd.DataFrame(datos3)
ipc_may25['Fecha'] = pd.to_datetime('20' + ipc_may25['Fecha'].str[-2:] + '-' + ipc_may25['Fecha'].str[:2] + '-01')

print(ipc_may25)
# Out:
#         Fecha     ipc
# 0  2024-01-01  2.0455
# 1  2024-02-01  1.8045
# 2  2024-03-01  1.6255
# 3  2024-04-01  1.5229
# 4  2024-05-01  1.4631
# 5  2024-06-01  1.4109
# 6  2024-07-01  1.3520
# 7  2024-08-01  1.2910
# 8  2024-09-01  1.2455
# 9  2024-10-01  1.2183
# 10 2024-11-01  1.1780
# 11 2024-12-01  1.1383
# 12 2025-01-01  1.1134
# 13 2025-02-01  1.0741
# 14 2025-03-01  1.0452
# 15 2025-04-01  1.0199
# 16 2025-05-01  1.0000
# 17 2025-06-01  0.9786
#         Fecha  Medicamentos  Descartables
# 0  2024-01-01        1.7269        1.3598
# 1  2024-02-01        1.6189        1.2347
# 2  2024-03-01        1.3671        1.1802
# 3  2024-04-01        1.3420        1.1228
# 4  2024-05-01        1.3081        1.0692
# 5  2024-06-01        1.2635        1.0574
# 6  2024-07-01        1.2173        1.0659
# 7  2024-08-01        1.1874        1.0470
# 8  2024-09-01        1.1577        1.0308
# 9  2024-10-01        1.1361        1.0239
# 10 2024-11-01        1.0848        1.0408
# 11 2024-12-01        1.0861        1.0412
# 12 2025-01-01        1.0751        1.0414
# 13 2025-02-01        1.0543        1.0591
# 14 2025-03-01        1.0390        1.0431
# 15 2025-04-01        1.0271        1.0178
# 16 2025-05-01        1.0000        1.0000
# 17 2025-06-01        0.9861        0.9807

# %%
# Convert 'fecha_comp_' to datetime and create 'month_year' column in devengado_combined_df
devengado_combined_df['fecha_comp_datetime'] = pd.to_datetime(devengado_combined_df['fecha_comp_'].str.strip(), format='%d/%m/%Y', errors='coerce')
devengado_combined_df['month_year'] = devengado_combined_df['fecha_comp_datetime'].dt.to_period('M').dt.to_timestamp()

# Merge with ipc_gral
merged_df = pd.merge(devengado_combined_df, ipc_gral, left_on='month_year', right_on='Fecha', how='left')

# Drop the duplicate 'Fecha' column from the merge
merged_df = merged_df.drop('Fecha', axis=1)

# Merge with ipc_may25
merged_df = pd.merge(merged_df, ipc_may25, left_on='month_year', right_on='Fecha', how='left')

# Drop the duplicate 'Fecha' column from the merge
merged_df = merged_df.drop('Fecha', axis=1)

print("First 5 rows of the merged dataframe:")
display(merged_df.head())

print("\nInformation about the merged dataframe:")
merged_df.info()
# Out:
# First 5 rows of the merged dataframe:
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 1  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 2  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 3  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 4  0425-501647/2024  PAGADO  Rentas   Generales   457-003
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#                ofic_solicitante_  ...  letra_fondo_  fecha_comp_   mes_comp_  \
# 0  DR. EMILIO VIDAL ABAL (OLIVA)  ...           NaN   04/01/2024  ENERO
# 1  DR. EMILIO VIDAL ABAL (OLIVA)  ...           NaN   04/01/2024  ENERO
# 2                         RAWSON  ...           NaN   04/01/2024  ENERO
# 3                         RAWSON  ...           NaN   04/01/2024  ENERO
# 4                         RAWSON  ...           NaN   03/01/2024  ENERO
#
#   letra_cch_ estado_item_ fecha_comp_datetime month_year     ipc Medicamentos  \
# 0        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 1        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 2        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 3        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 4        NaN     GENERADO          2024-01-03 2024-01-01  2.0455       1.7269
#
#   Descartables
# 0       1.3598
# 1       1.3598
# 2       1.3598
# 3       1.3598
# 4       1.3598
#
# [5 rows x 24 columns]
# Information about the merged dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423337 entries, 0 to 423336
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   referencia_            423337 non-null  object
#  1   tipo_doc_respaldo_     423337 non-null  object
#  2   n°_doc_respaldo_       423337 non-null  object
#  3   expediente_            267401 non-null  object
#  4   estado_                423337 non-null  object
#  5   grupo_                 422845 non-null  object
#  6   programa_              423337 non-null  object
#  7   descripcion_del_bien_  423337 non-null  object
#  8   n°_objeto_gasto_       423337 non-null  int64
#  9   ofic_solicitante_      423337 non-null  object
#  10  cantidad_              423337 non-null  float64
#  11  importe_unitario_      423337 non-null  float64
#  12  importe_por_item_      423337 non-null  float64
#  13  estado_compromiso_     49112 non-null   object
#  14  letra_fondo_           112570 non-null  object
#  15  fecha_comp_            423337 non-null  object
#  16  mes_comp_              423337 non-null  object
#  17  letra_cch_             112570 non-null  object
#  18  estado_item_           423337 non-null  object
#  19  fecha_comp_datetime    423319 non-null  datetime64[ns]
#  20  month_year             423319 non-null  datetime64[ns]
#  21  ipc                    399810 non-null  float64
#  22  Medicamentos           399810 non-null  float64
#  23  Descartables           399810 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(15)
# memory usage: 77.5+ MB

# %%
missing_ipc_rows = merged_df[merged_df['month_year'].isna()]
print("Rows with missing date or IPC values:")
display(missing_ipc_rows.head())

print(f"\nNumber of rows with missing date or IPC values: {len(missing_ipc_rows)}")
# Out:
# Rows with missing date or IPC values:
#        referencia_ tipo_doc_respaldo_ n°_doc_respaldo_ expediente_ estado_  \
# 9856   2024/005375             TICKET   00004-00014439         NaN  PAGADO
# 23632  2024/012475       HOJA DE RUTA             8016         NaN  PAGADO
# 61342  2024/029887             TICKET   00085-00102867         NaN  PAGADO
# 69615  2024/034143       HOJA DE RUTA              238         NaN  PAGADO
# 87789  2024/042200       HOJA DE RUTA       2687662402         NaN  PAGADO
#
#                    grupo_ programa_           descripcion_del_bien_  \
# 9856   Cuentas Especiales   454-000  GASTOS DE ALOJAMIENTO Y COMIDA
# 23632  Cuentas Especiales   464-000                        VIATICOS
# 61342  Rentas   Generales   450-000            SERVICIO DE DESAYUNO
# 69615  Cuentas Especiales   464-000                        VIATICOS
# 87789  Recursos Afectados   462-000                        VIATICOS
#
#        n°_objeto_gasto_     ofic_solicitante_  ...  letra_fondo_  fecha_comp_  \
# 9856            3080400               ECODAIC  ...           NaN   05/02/0202
# 23632           3080200  H. VILLA DEL ROSARIO  ...             R   11/01/0204
# 61342           3080400   MINISTERIO DE SALUD  ...           NaN   19/04/0204
# 69615           3080200       H. CRUZ DEL EJE  ...             R   26/04/0204
# 87789           3080200       H. MINA CLAVERO  ...             N   22/05/0202
#
#         mes_comp_ letra_cch_ estado_item_ fecha_comp_datetime month_year ipc  \
# 9856   FEBRERO           NaN     GENERADO                 NaT        NaT NaN
# 23632  ENERO              86     GENERADO                 NaT        NaT NaN
# 61342  ABRIL             NaN     GENERADO                 NaT        NaT NaN
# 69615  ABRIL              75     GENERADO                 NaT        NaT NaN
# 87789  MAYO              143     GENERADO                 NaT        NaT NaN
#
#       Medicamentos Descartables
# 9856           NaN          NaN
# 23632          NaN          NaN
# 61342          NaN          NaN
# 69615          NaN          NaN
# 87789          NaN          NaN
#
# [5 rows x 24 columns]
# Number of rows with missing date or IPC values: 18

# %%
print("Unique values in 'fecha_comp_' column:")
display(devengado_combined_df['fecha_comp_'].unique())

print("\nValue counts of 'fecha_comp_' column:")
display(devengado_combined_df['fecha_comp_'].value_counts())
# Out:
# Unique values in 'fecha_comp_' column:
# array([' 04/01/2024', ' 03/01/2024', ' 08/01/2024', ..., ' 02/08/2025',
#        ' 03/08/2025', ' 04/08/2025'], dtype=object)
# Value counts of 'fecha_comp_' column:
# fecha_comp_
# 25/06/2024    2608
# 30/04/2024    2473
# 25/01/2024    2435
# 25/11/2024    2426
# 25/04/2024    2387
#               ...
# 23/11/2022       1
# 02/12/2022       1
# 23/09/2022       1
# 06/08/2023       1
# 12/07/2022       1
# Name: count, Length: 1080, dtype: int64

# %%
missing_ipc_rows = merged_df[merged_df['ipc'].isna()]
print("Rows with missing IPC values:")
display(missing_ipc_rows.head())

print(f"\nNumber of rows with missing IPC values: {len(missing_ipc_rows)}")

# Check the date range of the merged dataframe where IPC is missing
if not missing_ipc_rows.empty:
    print("\nDate range of rows with missing IPC values:")
    display(missing_ipc_rows['fecha_comp_datetime'].min())
    display(missing_ipc_rows['fecha_comp_datetime'].max())

# Check the date range of the IPC dataframes
print("\nDate range of ipc_gral:")
display(ipc_gral['Fecha'].min())
display(ipc_gral['Fecha'].max())

print("\nDate range of ipc_may25:")
display(ipc_may25['Fecha'].min())
display(ipc_may25['Fecha'].max())
# Out:
# Rows with missing IPC values:
#     referencia_ tipo_doc_respaldo_ n°_doc_respaldo_       expediente_ estado_  \
# 39  2024/000024             TICKET   00009-00018504  0425-501414/2024  PAGADO
# 40  2024/000024             TICKET   00009-00018504  0425-501414/2024  PAGADO
# 41  2024/000024             TICKET   00009-00018504  0425-501414/2024  PAGADO
# 42  2024/000024             TICKET   00009-00018504  0425-501414/2024  PAGADO
# 43  2024/000024             TICKET   00009-00018504  0425-501414/2024  PAGADO
#
#                 grupo_ programa_ descripcion_del_bien_  n°_objeto_gasto_  \
# 39  Rentas   Generales   458-026        CREMA DE LECHE           2010200
# 40  Rentas   Generales   458-026               FIAMBRE           2010200
# 41  Rentas   Generales   458-026               MANTECA           2010200
# 42  Rentas   Generales   458-026       TAPA PASCUALINA           2010200
# 43  Rentas   Generales   458-026                 DULCE           2010200
#
#     ofic_solicitante_  ...  letra_fondo_  fecha_comp_   mes_comp_ letra_cch_  \
# 39  H. HUINCA RENANCÓ  ...           NaN   23/11/2023  NOVIEMBRE         NaN
# 40  H. HUINCA RENANCÓ  ...           NaN   23/11/2023  NOVIEMBRE         NaN
# 41  H. HUINCA RENANCÓ  ...           NaN   23/11/2023  NOVIEMBRE         NaN
# 42  H. HUINCA RENANCÓ  ...           NaN   23/11/2023  NOVIEMBRE         NaN
# 43  H. HUINCA RENANCÓ  ...           NaN   23/11/2023  NOVIEMBRE         NaN
#
#    estado_item_ fecha_comp_datetime month_year ipc Medicamentos Descartables
# 39     GENERADO          2023-11-23 2023-11-01 NaN          NaN          NaN
# 40     GENERADO          2023-11-23 2023-11-01 NaN          NaN          NaN
# 41     GENERADO          2023-11-23 2023-11-01 NaN          NaN          NaN
# 42     GENERADO          2023-11-23 2023-11-01 NaN          NaN          NaN
# 43     GENERADO          2023-11-23 2023-11-01 NaN          NaN          NaN
#
# [5 rows x 24 columns]
# Number of rows with missing IPC values: 23527
#
# Date range of rows with missing IPC values:
# Timestamp('2010-11-26 00:00:00')
# Timestamp('2025-08-04 00:00:00')
# Date range of ipc_gral:
# Timestamp('2024-01-01 00:00:00')
# Timestamp('2025-06-01 00:00:00')
# Date range of ipc_may25:
# Timestamp('2024-01-01 00:00:00')
# Timestamp('2025-06-01 00:00:00')

# %%
# Define the minimum date based on the IPC data
min_ipc_date = pd.to_datetime('2024-01-01')

# Filter the merged dataframe to include only rows within or after the minimum IPC date
# This will now include data after the IPC date range as requested
merged_df_filtered = merged_df[
    merged_df['fecha_comp_datetime'] >= min_ipc_date
].copy() # Use .copy() to avoid SettingWithCopyWarning

print("First 5 rows of the filtered dataframe:")
display(merged_df_filtered.head())

print("\nInformation about the filtered dataframe:")
merged_df_filtered.info()
# Out:
# First 5 rows of the filtered dataframe:
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 1  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 2  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 3  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 4  0425-501647/2024  PAGADO  Rentas   Generales   457-003
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#                ofic_solicitante_  ...  letra_fondo_  fecha_comp_   mes_comp_  \
# 0  DR. EMILIO VIDAL ABAL (OLIVA)  ...           NaN   04/01/2024  ENERO
# 1  DR. EMILIO VIDAL ABAL (OLIVA)  ...           NaN   04/01/2024  ENERO
# 2                         RAWSON  ...           NaN   04/01/2024  ENERO
# 3                         RAWSON  ...           NaN   04/01/2024  ENERO
# 4                         RAWSON  ...           NaN   03/01/2024  ENERO
#
#   letra_cch_ estado_item_ fecha_comp_datetime month_year     ipc Medicamentos  \
# 0        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 1        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 2        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 3        NaN     GENERADO          2024-01-04 2024-01-01  2.0455       1.7269
# 4        NaN     GENERADO          2024-01-03 2024-01-01  2.0455       1.7269
#
#   Descartables
# 0       1.3598
# 1       1.3598
# 2       1.3598
# 3       1.3598
# 4       1.3598
#
# [5 rows x 24 columns]
# Information about the filtered dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Index: 411189 entries, 0 to 423336
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   referencia_            411189 non-null  object
#  1   tipo_doc_respaldo_     411189 non-null  object
#  2   n°_doc_respaldo_       411189 non-null  object
#  3   expediente_            259441 non-null  object
#  4   estado_                411189 non-null  object
#  5   grupo_                 410697 non-null  object
#  6   programa_              411189 non-null  object
#  7   descripcion_del_bien_  411189 non-null  object
#  8   n°_objeto_gasto_       411189 non-null  int64
#  9   ofic_solicitante_      411189 non-null  object
#  10  cantidad_              411189 non-null  float64
#  11  importe_unitario_      411189 non-null  float64
#  12  importe_por_item_      411189 non-null  float64
#  13  estado_compromiso_     47729 non-null   object
#  14  letra_fondo_           108274 non-null  object
#  15  fecha_comp_            411189 non-null  object
#  16  mes_comp_              411189 non-null  object
#  17  letra_cch_             108274 non-null  object
#  18  estado_item_           411189 non-null  object
#  19  fecha_comp_datetime    411189 non-null  datetime64[ns]
#  20  month_year             411189 non-null  datetime64[ns]
#  21  ipc                    399810 non-null  float64
#  22  Medicamentos           399810 non-null  float64
#  23  Descartables           399810 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(15)
# memory usage: 78.4+ MB

# %%
# Create a copy to avoid modifying the original merged dataframe
processed_df = merged_df_filtered.copy()

# Modify 'ofic_solicitante_' column: first remove ' SIN OC/OCD' and then standardize the names
processed_df['ofic_solicitante_'] = processed_df['ofic_solicitante_'].str.replace(' SIN OC/OCD', '', regex=False)

# Standardize 'DR. EMILIO VIDAL ABAL (OLIVA)' to 'H. VIDAL ABAL'
processed_df['ofic_solicitante_'] = processed_df['ofic_solicitante_'].replace('DR. EMILIO VIDAL ABAL (OLIVA)', 'H. VIDAL ABAL')


# Calculate real spending using the appropriate IPC values
# Create a mapping for specific object codes to specific IPC columns
ipc_mapping = {
    2060100: 'Medicamentos', # Assuming this object code corresponds to Medicamentos
    2060200: 'Descartables' # Assuming this object code corresponds to Descartables
}

# Apply the appropriate IPC based on 'n°_objeto_gasto_'
# If IPC is missing, use the original 'importe_por_item_' value
processed_df['relevant_ipc'] = processed_df.apply(
    lambda row: row[ipc_mapping.get(row['n°_objeto_gasto_'], 'ipc')] if pd.notna(row['n°_objeto_gasto_']) and pd.notna(row['ipc']) else (1 if pd.isna(row['ipc']) else row['ipc']), axis=1
)


# Calculate adjusted spending
# If relevant_ipc is 1 (due to missing original IPC), use the original importe_por_item_
processed_df['importe_unitario_may25'] = processed_df.apply(
    lambda row: row['importe_unitario_'] * row['relevant_ipc'] if pd.notna(row['relevant_ipc']) else row['importe_unitario_'], axis=1
)
processed_df['importe_por_item_may25'] = processed_df.apply(
    lambda row: row['importe_por_item_'] * row['relevant_ipc'] if pd.notna(row['relevant_ipc']) else row['importe_por_item_'], axis=1
)


print("First 5 rows of the dataframe after removing ' SIN OC/OCD', standardizing office names, and calculating adjusted spending:")
display(processed_df.head())

print("\nInformation about the dataframe after removing ' SIN OC/OCD', standardizing office names, and calculating adjusted spending:")
processed_df.info()
# Out:
# First 5 rows of the dataframe after removing ' SIN OC/OCD', standardizing office names, and calculating adjusted spending:
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 1  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 2  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 3  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 4  0425-501647/2024  PAGADO  Rentas   Generales   457-003
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#   ofic_solicitante_  ...  letra_cch_  estado_item_  fecha_comp_datetime  \
# 0     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 1     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 2            RAWSON  ...         NaN      GENERADO           2024-01-04
# 3            RAWSON  ...         NaN      GENERADO           2024-01-04
# 4            RAWSON  ...         NaN      GENERADO           2024-01-03
#
#   month_year     ipc Medicamentos Descartables relevant_ipc  \
# 0 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 2 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 3 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 4 2024-01-01  2.0455       1.7269       1.3598       1.3598
#
#   importe_unitario_may25 importe_por_item_may25
# 0           1.088625e+06           1.088625e+06
# 1           6.207095e+05           6.207095e+05
# 2           5.871460e+02           8.807190e+04
# 3           1.588748e+02           6.196117e+04
# 4           7.479534e+05           2.991814e+06
#
# [5 rows x 27 columns]
# Information about the dataframe after removing ' SIN OC/OCD', standardizing office names, and calculating adjusted spending:
# <class 'pandas.core.frame.DataFrame'>
# Index: 411189 entries, 0 to 423336
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   referencia_             411189 non-null  object
#  1   tipo_doc_respaldo_      411189 non-null  object
#  2   n°_doc_respaldo_        411189 non-null  object
#  3   expediente_             259441 non-null  object
#  4   estado_                 411189 non-null  object
#  5   grupo_                  410697 non-null  object
#  6   programa_               411189 non-null  object
#  7   descripcion_del_bien_   411189 non-null  object
#  8   n°_objeto_gasto_        411189 non-null  int64
#  9   ofic_solicitante_       411189 non-null  object
#  10  cantidad_               411189 non-null  float64
#  11  importe_unitario_       411189 non-null  float64
#  12  importe_por_item_       411189 non-null  float64
#  13  estado_compromiso_      47729 non-null   object
#  14  letra_fondo_            108274 non-null  object
#  15  fecha_comp_             411189 non-null  object
#  16  mes_comp_               411189 non-null  object
#  17  letra_cch_              108274 non-null  object
#  18  estado_item_            411189 non-null  object
#  19  fecha_comp_datetime     411189 non-null  datetime64[ns]
#  20  month_year              411189 non-null  datetime64[ns]
#  21  ipc                     399810 non-null  float64
#  22  Medicamentos            399810 non-null  float64
#  23  Descartables            399810 non-null  float64
#  24  relevant_ipc            411189 non-null  float64
#  25  importe_unitario_may25  411189 non-null  float64
#  26  importe_por_item_may25  411189 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1), object(15)
# memory usage: 87.8+ MB

# %%
processed_df_filtered_commitment = processed_df[processed_df['estado_compromiso_'].isna()].copy()

print("First 5 rows of the dataframe filtered by null 'estado_compromiso_':")
display(processed_df_filtered_commitment.head())

print("\nInformation about the filtered dataframe:")
processed_df_filtered_commitment.info()
# Out:
# First 5 rows of the dataframe filtered by null 'estado_compromiso_':
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 1  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 2  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 3  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 4  0425-501647/2024  PAGADO  Rentas   Generales   457-003
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#   ofic_solicitante_  ...  letra_cch_  estado_item_  fecha_comp_datetime  \
# 0     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 1     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 2            RAWSON  ...         NaN      GENERADO           2024-01-04
# 3            RAWSON  ...         NaN      GENERADO           2024-01-04
# 4            RAWSON  ...         NaN      GENERADO           2024-01-03
#
#   month_year     ipc Medicamentos Descartables relevant_ipc  \
# 0 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 2 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 3 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 4 2024-01-01  2.0455       1.7269       1.3598       1.3598
#
#   importe_unitario_may25 importe_por_item_may25
# 0           1.088625e+06           1.088625e+06
# 1           6.207095e+05           6.207095e+05
# 2           5.871460e+02           8.807190e+04
# 3           1.588748e+02           6.196117e+04
# 4           7.479534e+05           2.991814e+06
#
# [5 rows x 27 columns]
# Information about the filtered dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Index: 363460 entries, 0 to 423336
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   referencia_             363460 non-null  object
#  1   tipo_doc_respaldo_      363460 non-null  object
#  2   n°_doc_respaldo_        363460 non-null  object
#  3   expediente_             211842 non-null  object
#  4   estado_                 363460 non-null  object
#  5   grupo_                  363111 non-null  object
#  6   programa_               363460 non-null  object
#  7   descripcion_del_bien_   363460 non-null  object
#  8   n°_objeto_gasto_        363460 non-null  int64
#  9   ofic_solicitante_       363460 non-null  object
#  10  cantidad_               363460 non-null  float64
#  11  importe_unitario_       363460 non-null  float64
#  12  importe_por_item_       363460 non-null  float64
#  13  estado_compromiso_      0 non-null       object
#  14  letra_fondo_            108096 non-null  object
#  15  fecha_comp_             363460 non-null  object
#  16  mes_comp_               363460 non-null  object
#  17  letra_cch_              108096 non-null  object
#  18  estado_item_            363460 non-null  object
#  19  fecha_comp_datetime     363460 non-null  datetime64[ns]
#  20  month_year              363460 non-null  datetime64[ns]
#  21  ipc                     352484 non-null  float64
#  22  Medicamentos            352484 non-null  float64
#  23  Descartables            352484 non-null  float64
#  24  relevant_ipc            363460 non-null  float64
#  25  importe_unitario_may25  363460 non-null  float64
#  26  importe_por_item_may25  363460 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1), object(15)
# memory usage: 77.6+ MB

# %%
oficinas_a_mantener = [
    'DR. EMILIO VIDAL ABAL (OLIVA)', 'RAWSON', 'H. ALTA GRACIA', 'H. LA CALERA',
    'H. RÍO CUARTO', 'H. VILLA MARÍA', 'CÓRDOBA', 'H. MINA CLAVERO', 'H. LABOULAYE',
    'H. NEUROPSIQUIÁTRICO', 'FLORENCIO DIAZ', 'H. DEÁN FUNES', 'MATERNO PROVINCIAL',
    'SUROESTE EVA PERÓN', 'TRÁNSITO', 'H. SAN JOSÉ DE LA DORMIDA', 'H. DOMINGO FUNES',
    'H. OLIVA', 'MISERICORDIA', 'PEDIÁTRICO', 'ELPIDIO TORRES', 'H. RÍO TERCERO',
    'H. SAN FRANCISCO', 'ONCOLÓGICO', 'H. JESUS MARÍA', 'H. BELL VILLE',
    'H. VILLA DEL ROSARIO', 'H. CALAMUCHITA', 'H. VILLA DOLORES', 'H. LA CARLOTA',
    'NIÑOS', 'NEONATAL', 'H. HUINCA RENANCÓ', 'H. SAN FRANCISCO DEL CHAÑAR',
    'H. CRUZ DEL EJE', 'H. CORRAL DE BUSTOS', 'H. SANTA ROSA DE RÍO PRIMERO',
    'H. MARCOS JUAREZ', 'SAN ROQUE', 'H. COLONIA SANTA MARÍA', 'H. VIDAL ABAL',
    'H. UNQUILLO', 'CASA DEL JOVEN', 'CRSL'
]

# Create a condition for offices in the list or ending with ' SIN OC/OCD' and in the list
condition = processed_df['ofic_solicitante_'].apply(lambda x: x in oficinas_a_mantener or (isinstance(x, str) and x.replace(' SIN OC/OCD', '') in oficinas_a_mantener))

processed_df_filtered_oficinas = processed_df[condition].copy()

# Update 'ofic_solicitante_' for rows ending with ' SIN OC/OCD'
processed_df_filtered_oficinas['ofic_solicitante_'] = processed_df_filtered_oficinas['ofic_solicitante_'].str.replace(' SIN OC/OCD', '', regex=False)

print("First 5 rows of the dataframe filtered and updated 'ofic_solicitante_':")
display(processed_df_filtered_oficinas.head())

print("\nInformation about the filtered and updated dataframe:")
processed_df_filtered_oficinas.info()

print("\nUnique values in 'ofic_solicitante_' column after update:")
display(processed_df_filtered_oficinas['ofic_solicitante_'].unique())
# Out:
# First 5 rows of the dataframe filtered and updated 'ofic_solicitante_':
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 1  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 2  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 3  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 4  0425-501647/2024  PAGADO  Rentas   Generales   457-003
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#   ofic_solicitante_  ...  letra_cch_  estado_item_  fecha_comp_datetime  \
# 0     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 1     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 2            RAWSON  ...         NaN      GENERADO           2024-01-04
# 3            RAWSON  ...         NaN      GENERADO           2024-01-04
# 4            RAWSON  ...         NaN      GENERADO           2024-01-03
#
#   month_year     ipc Medicamentos Descartables relevant_ipc  \
# 0 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 2 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 3 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 4 2024-01-01  2.0455       1.7269       1.3598       1.3598
#
#   importe_unitario_may25 importe_por_item_may25
# 0           1.088625e+06           1.088625e+06
# 1           6.207095e+05           6.207095e+05
# 2           5.871460e+02           8.807190e+04
# 3           1.588748e+02           6.196117e+04
# 4           7.479534e+05           2.991814e+06
#
# [5 rows x 27 columns]
# Information about the filtered and updated dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283574 entries, 0 to 423336
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   referencia_             283574 non-null  object
#  1   tipo_doc_respaldo_      283574 non-null  object
#  2   n°_doc_respaldo_        283574 non-null  object
#  3   expediente_             191945 non-null  object
#  4   estado_                 283574 non-null  object
#  5   grupo_                  283574 non-null  object
#  6   programa_               283574 non-null  object
#  7   descripcion_del_bien_   283574 non-null  object
#  8   n°_objeto_gasto_        283574 non-null  int64
#  9   ofic_solicitante_       283574 non-null  object
#  10  cantidad_               283574 non-null  float64
#  11  importe_unitario_       283574 non-null  float64
#  12  importe_por_item_       283574 non-null  float64
#  13  estado_compromiso_      34688 non-null   object
#  14  letra_fondo_            91554 non-null   object
#  15  fecha_comp_             283574 non-null  object
#  16  mes_comp_               283574 non-null  object
#  17  letra_cch_              91554 non-null   object
#  18  estado_item_            283574 non-null  object
#  19  fecha_comp_datetime     283574 non-null  datetime64[ns]
#  20  month_year              283574 non-null  datetime64[ns]
#  21  ipc                     275067 non-null  float64
#  22  Medicamentos            275067 non-null  float64
#  23  Descartables            275067 non-null  float64
#  24  relevant_ipc            283574 non-null  float64
#  25  importe_unitario_may25  283574 non-null  float64
#  26  importe_por_item_may25  283574 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1), object(15)
# memory usage: 60.6+ MB
#
# Unique values in 'ofic_solicitante_' column after update:
# array(['H. VIDAL ABAL', 'RAWSON', 'H. ALTA GRACIA', 'H. LA CALERA',
#        'H. RÍO CUARTO', 'H. VILLA MARÍA', 'CÓRDOBA', 'H. MINA CLAVERO',
#        'H. LABOULAYE', 'H. NEUROPSIQUIÁTRICO', 'FLORENCIO DIAZ',
#        'H. DEÁN FUNES', 'MATERNO PROVINCIAL', 'SUROESTE EVA PERÓN',
#        'TRÁNSITO', 'H. SAN JOSÉ DE LA DORMIDA', 'H. DOMINGO FUNES',
#        'H. OLIVA', 'MISERICORDIA', 'PEDIÁTRICO', 'ELPIDIO TORRES',
#        'H. RÍO TERCERO', 'H. SAN FRANCISCO', 'ONCOLÓGICO',
#        'H. JESUS MARÍA', 'H. BELL VILLE', 'H. VILLA DEL ROSARIO',
#        'H. CALAMUCHITA', 'H. VILLA DOLORES', 'H. LA CARLOTA', 'NIÑOS',
#        'NEONATAL', 'H. HUINCA RENANCÓ', 'H. SAN FRANCISCO DEL CHAÑAR',
#        'H. CRUZ DEL EJE', 'H. CORRAL DE BUSTOS',
#        'H. SANTA ROSA DE RÍO PRIMERO', 'H. MARCOS JUAREZ', 'SAN ROQUE',
#        'H. COLONIA SANTA MARÍA', 'H. UNQUILLO', 'CASA DEL JOVEN', 'CRSL'],
#       dtype=object)

# %%
processed_df_filtered_oficinas_commitment_null = processed_df_filtered_oficinas[processed_df_filtered_oficinas['estado_compromiso_'].isna()].copy()

print("First 5 rows of the dataframe filtered by null 'estado_compromiso_':")
display(processed_df_filtered_oficinas_commitment_null.head())

print("\nInformation about the filtered dataframe:")
processed_df_filtered_oficinas_commitment_null.info()
# Out:
# First 5 rows of the dataframe filtered by null 'estado_compromiso_':
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 1  0425-505607/2024  PAGADO  Rentas   Generales   461-002
# 2  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 3  0425-501643/2024  PAGADO  Rentas   Generales   457-003
# 4  0425-501647/2024  PAGADO  Rentas   Generales   457-003
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#   ofic_solicitante_  ...  letra_cch_  estado_item_  fecha_comp_datetime  \
# 0     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 1     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 2            RAWSON  ...         NaN      GENERADO           2024-01-04
# 3            RAWSON  ...         NaN      GENERADO           2024-01-04
# 4            RAWSON  ...         NaN      GENERADO           2024-01-03
#
#   month_year     ipc Medicamentos Descartables relevant_ipc  \
# 0 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 2 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 3 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 4 2024-01-01  2.0455       1.7269       1.3598       1.3598
#
#   importe_unitario_may25 importe_por_item_may25
# 0           1.088625e+06           1.088625e+06
# 1           6.207095e+05           6.207095e+05
# 2           5.871460e+02           8.807190e+04
# 3           1.588748e+02           6.196117e+04
# 4           7.479534e+05           2.991814e+06
#
# [5 rows x 27 columns]
# Information about the filtered dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Index: 248886 entries, 0 to 423336
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   referencia_             248886 non-null  object
#  1   tipo_doc_respaldo_      248886 non-null  object
#  2   n°_doc_respaldo_        248886 non-null  object
#  3   expediente_             157328 non-null  object
#  4   estado_                 248886 non-null  object
#  5   grupo_                  248886 non-null  object
#  6   programa_               248886 non-null  object
#  7   descripcion_del_bien_   248886 non-null  object
#  8   n°_objeto_gasto_        248886 non-null  int64
#  9   ofic_solicitante_       248886 non-null  object
#  10  cantidad_               248886 non-null  float64
#  11  importe_unitario_       248886 non-null  float64
#  12  importe_por_item_       248886 non-null  float64
#  13  estado_compromiso_      0 non-null       object
#  14  letra_fondo_            91515 non-null   object
#  15  fecha_comp_             248886 non-null  object
#  16  mes_comp_               248886 non-null  object
#  17  letra_cch_              91515 non-null   object
#  18  estado_item_            248886 non-null  object
#  19  fecha_comp_datetime     248886 non-null  datetime64[ns]
#  20  month_year              248886 non-null  datetime64[ns]
#  21  ipc                     240548 non-null  float64
#  22  Medicamentos            240548 non-null  float64
#  23  Descartables            240548 non-null  float64
#  24  relevant_ipc            248886 non-null  float64
#  25  importe_unitario_may25  248886 non-null  float64
#  26  importe_por_item_may25  248886 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1), object(15)
# memory usage: 53.2+ MB

# %%
print("Unique values in 'ofic_solicitante_' column:")
display(processed_df_filtered_oficinas_commitment_null['ofic_solicitante_'].unique())
# Out:
# Unique values in 'ofic_solicitante_' column:
# array(['H. VIDAL ABAL', 'RAWSON', 'H. ALTA GRACIA', 'H. LA CALERA',
#        'H. RÍO CUARTO', 'H. VILLA MARÍA', 'CÓRDOBA', 'H. MINA CLAVERO',
#        'H. LABOULAYE', 'H. NEUROPSIQUIÁTRICO', 'FLORENCIO DIAZ',
#        'H. DEÁN FUNES', 'MATERNO PROVINCIAL', 'SUROESTE EVA PERÓN',
#        'TRÁNSITO', 'H. SAN JOSÉ DE LA DORMIDA', 'H. DOMINGO FUNES',
#        'H. OLIVA', 'MISERICORDIA', 'PEDIÁTRICO', 'ELPIDIO TORRES',
#        'H. RÍO TERCERO', 'H. SAN FRANCISCO', 'ONCOLÓGICO',
#        'H. JESUS MARÍA', 'H. BELL VILLE', 'H. VILLA DEL ROSARIO',
#        'H. CALAMUCHITA', 'H. VILLA DOLORES', 'H. LA CARLOTA', 'NIÑOS',
#        'NEONATAL', 'H. HUINCA RENANCÓ', 'H. SAN FRANCISCO DEL CHAÑAR',
#        'H. CRUZ DEL EJE', 'H. CORRAL DE BUSTOS',
#        'H. SANTA ROSA DE RÍO PRIMERO', 'H. MARCOS JUAREZ', 'SAN ROQUE',
#        'H. COLONIA SANTA MARÍA', 'H. UNQUILLO', 'CASA DEL JOVEN', 'CRSL'],
#       dtype=object)

# %%
processed_df_filtered_oficinas_commitment_null['programa_'] = processed_df_filtered_oficinas_commitment_null['programa_'].str[:3]

print("First 5 rows of the dataframe with modified 'programa_' column:")
display(processed_df_filtered_oficinas_commitment_null.head())

print("\nUnique values in 'programa_' column after modification:")
display(processed_df_filtered_oficinas_commitment_null['programa_'].unique())
# Out:
# First 5 rows of the dataframe with modified 'programa_' column:
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales       461
# 1  0425-505607/2024  PAGADO  Rentas   Generales       461
# 2  0425-501643/2024  PAGADO  Rentas   Generales       457
# 3  0425-501643/2024  PAGADO  Rentas   Generales       457
# 4  0425-501647/2024  PAGADO  Rentas   Generales       457
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#   ofic_solicitante_  ...  letra_cch_  estado_item_  fecha_comp_datetime  \
# 0     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 1     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 2            RAWSON  ...         NaN      GENERADO           2024-01-04
# 3            RAWSON  ...         NaN      GENERADO           2024-01-04
# 4            RAWSON  ...         NaN      GENERADO           2024-01-03
#
#   month_year     ipc Medicamentos Descartables relevant_ipc  \
# 0 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 2 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 3 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 4 2024-01-01  2.0455       1.7269       1.3598       1.3598
#
#   importe_unitario_may25 importe_por_item_may25
# 0           1.088625e+06           1.088625e+06
# 1           6.207095e+05           6.207095e+05
# 2           5.871460e+02           8.807190e+04
# 3           1.588748e+02           6.196117e+04
# 4           7.479534e+05           2.991814e+06
#
# [5 rows x 27 columns]
# Unique values in 'programa_' column after modification:
# array(['461', '457', '458', '462', '464', '463', '470', '456'],
#       dtype=object)

# %%
programas_a_mantener = ['457', '458', '461', '462', '464']

# Add filtering based on 'n°_objeto_gasto_'
object_codes_to_exclude_prefix = ['312', '313', '315', '32', '39']
condition_object_code = ~processed_df_filtered_oficinas_commitment_null['n°_objeto_gasto_'].astype(str).str.startswith(tuple(object_codes_to_exclude_prefix), na=False)

# Add filtering to exclude rows with 'SERVICIOS DE ESTERILIZACION' in 'descripcion_del_bien_'
condition_esterilizacion = ~processed_df_filtered_oficinas_commitment_null['descripcion_del_bien_'].str.contains('SERVICIOS DE ESTERILIZACION', na=False)


processed_df_filtered_programas = processed_df_filtered_oficinas_commitment_null[
    processed_df_filtered_oficinas_commitment_null['programa_'].isin(programas_a_mantener) &
    condition_object_code &
    condition_esterilizacion # Add the new condition here
].copy()

print("First 5 rows of the dataframe filtered by specific 'programa_' and excluded object codes:")
display(processed_df_filtered_programas.head())

print("\nInformation about the filtered dataframe:")
processed_df_filtered_programas.info()

print("\nUnique values in 'programa_' column after filtering:")
display(processed_df_filtered_programas['programa_'].unique())
# Out:
# First 5 rows of the dataframe filtered by specific 'programa_' and excluded object codes:
#    referencia_                 tipo_doc_respaldo_ n°_doc_respaldo_  \
# 0  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 1  2024/000002  LIQUIDACIÓN DE SERVICIOS PÚBLICOS    0400-49501051
# 2  2024/000003                            FACTURA   00004-00007708
# 3  2024/000003                            FACTURA   00004-00007708
# 4  2024/000004                            FACTURA   00003-00005812
#
#         expediente_ estado_              grupo_ programa_  \
# 0  0425-505607/2024  PAGADO  Rentas   Generales       461
# 1  0425-505607/2024  PAGADO  Rentas   Generales       461
# 2  0425-501643/2024  PAGADO  Rentas   Generales       457
# 3  0425-501643/2024  PAGADO  Rentas   Generales       457
# 4  0425-501647/2024  PAGADO  Rentas   Generales       457
#
#                                descripcion_del_bien_  n°_objeto_gasto_  \
# 0  INTERESES DE DEUDAS CON PROVEEDORES Y CONTRATI...           5050100
# 1                          SUMINISTRO DE GAS NATURAL           3010300
# 2                                         CILOSTAZOL           2060100
# 3                                  DICLOFENAC SODICO           2060100
# 4                                            CANULAS           2060200
#
#   ofic_solicitante_  ...  letra_cch_  estado_item_  fecha_comp_datetime  \
# 0     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 1     H. VIDAL ABAL  ...         NaN      GENERADO           2024-01-04
# 2            RAWSON  ...         NaN      GENERADO           2024-01-04
# 3            RAWSON  ...         NaN      GENERADO           2024-01-04
# 4            RAWSON  ...         NaN      GENERADO           2024-01-03
#
#   month_year     ipc Medicamentos Descartables relevant_ipc  \
# 0 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 2 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 3 2024-01-01  2.0455       1.7269       1.3598       1.7269
# 4 2024-01-01  2.0455       1.7269       1.3598       1.3598
#
#   importe_unitario_may25 importe_por_item_may25
# 0           1.088625e+06           1.088625e+06
# 1           6.207095e+05           6.207095e+05
# 2           5.871460e+02           8.807190e+04
# 3           1.588748e+02           6.196117e+04
# 4           7.479534e+05           2.991814e+06
#
# [5 rows x 27 columns]
# Information about the filtered dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244305 entries, 0 to 423336
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   referencia_             244305 non-null  object
#  1   tipo_doc_respaldo_      244305 non-null  object
#  2   n°_doc_respaldo_        244305 non-null  object
#  3   expediente_             153248 non-null  object
#  4   estado_                 244305 non-null  object
#  5   grupo_                  244305 non-null  object
#  6   programa_               244305 non-null  object
#  7   descripcion_del_bien_   244305 non-null  object
#  8   n°_objeto_gasto_        244305 non-null  int64
#  9   ofic_solicitante_       244305 non-null  object
#  10  cantidad_               244305 non-null  float64
#  11  importe_unitario_       244305 non-null  float64
#  12  importe_por_item_       244305 non-null  float64
#  13  estado_compromiso_      0 non-null       object
#  14  letra_fondo_            91067 non-null   object
#  15  fecha_comp_             244305 non-null  object
#  16  mes_comp_               244305 non-null  object
#  17  letra_cch_              91067 non-null   object
#  18  estado_item_            244305 non-null  object
#  19  fecha_comp_datetime     244305 non-null  datetime64[ns]
#  20  month_year              244305 non-null  datetime64[ns]
#  21  ipc                     236015 non-null  float64
#  22  Medicamentos            236015 non-null  float64
#  23  Descartables            236015 non-null  float64
#  24  relevant_ipc            244305 non-null  float64
#  25  importe_unitario_may25  244305 non-null  float64
#  26  importe_por_item_may25  244305 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1), object(15)
# memory usage: 52.2+ MB
#
# Unique values in 'programa_' column after filtering:
# array(['461', '457', '458', '462', '464'], dtype=object)

# %%
num_unique_oficinas = processed_df_filtered_programas['ofic_solicitante_'].nunique()

print(f"Number of unique offices remaining after the last filter: {num_unique_oficinas}")
# Out:
# Number of unique offices remaining after the last filter: 43

# %%
monthly_spending_by_office = processed_df_filtered_programas.groupby(['ofic_solicitante_', 'month_year'])[['importe_por_item_', 'importe_por_item_may25']].sum().reset_index()

print("Monthly spending by office:")
display(monthly_spending_by_office.head())

print("\nInformation about the monthly spending dataframe:")
monthly_spending_by_office.info()
# Out:
# Monthly spending by office:
#   ofic_solicitante_ month_year  importe_por_item_  importe_por_item_may25
# 0    CASA DEL JOVEN 2024-01-01            8350.00            17079.925000
# 1    CASA DEL JOVEN 2024-02-01           13675.00            24676.537500
# 2    CASA DEL JOVEN 2024-03-01          475546.30           773000.510650
# 3    CASA DEL JOVEN 2024-04-01          183192.24           278983.462296
# 4    CASA DEL JOVEN 2024-05-01          326072.38           477076.499178
# Information about the monthly spending dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       833 non-null    object
#  1   month_year              833 non-null    datetime64[ns]
#  2   importe_por_item_       833 non-null    float64
#  3   importe_por_item_may25  833 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 26.2+ KB

# %%
from ipywidgets import Dropdown
import pandas as pd

# Get the unique list of office names
unique_offices = monthly_spending_by_office['ofic_solicitante_'].unique().tolist()

# Create a dropdown widget instance
office_dropdown = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

print("Dropdown widget created.")
# Out:
# Dropdown widget created.

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

def plot_office_spending(office_name):
    """
    Generates a time series plot of adjusted monthly spending for a given office.

    Args:
        office_name (str): The name of the office to plot.
    """
    # Filter data for the selected office
    office_data = monthly_spending_by_office[monthly_spending_by_office['ofic_solicitante_'] == office_name]

    # Create a matplotlib figure and axes
    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Create the time series plot using seaborn
    sb.lineplot(data=office_data, x='month_year', y='importe_por_item_may25', ax=ax)

    # Set plot title and labels
    ax.set_title(f'Gasto Mensual para {office_name} (Ajustado a Precios Mayo 2025)')
    ax.set_xlabel('Mes')
    ax.set_ylabel('Gasto Mensual (Millones de ARS)') # Updated y-axis label

    # Format y-axis labels to show millions
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/1000000:.2f}M'))

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Ensure layout is tight to prevent labels overlapping
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Modified the plot_office_spending function to display y-axis in millions.")
# Out:
# Modified the plot_office_spending function to display y-axis in millions.

# %%
from ipywidgets import interactive

# Link the dropdown to the plotting function using interactive
interactive_plot = interactive(plot_office_spending, office_name=office_dropdown)

print("Interactive plot linked to the dropdown.")
# Out:
# Interactive plot linked to the dropdown.

# %%
from ipywidgets import interactive

# Link the dropdown to the plotting function using interactive
interactive_plot = interactive(plot_office_spending, office_name=office_dropdown)

print("Interactive plot linked to the dropdown.")
# Out:
# Interactive plot linked to the dropdown.

# %%
# Calculate the overall average monthly spending across all offices
overall_monthly_average_spending = monthly_spending_by_office.groupby('month_year')['importe_por_item_may25'].mean().reset_index()

print("Overall average monthly spending across all offices:")
display(overall_monthly_average_spending.head())

print("\nInformation about the overall average monthly spending dataframe:")
overall_monthly_average_spending.info()
# Out:
# Overall average monthly spending across all offices:
#   month_year  importe_por_item_may25
# 0 2024-01-01            2.315694e+08
# 1 2024-02-01            2.025758e+08
# 2 2024-03-01            1.768313e+08
# 3 2024-04-01            1.984127e+08
# 4 2024-05-01            2.261349e+08
# Information about the overall average monthly spending dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   month_year              20 non-null     datetime64[ns]
#  1   importe_por_item_may25  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 452.0 bytes

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

def plot_office_spending(office_name):
    """
    Generates a time series plot of adjusted monthly spending for a given office,
    including a line for the overall average monthly spending across all offices.

    Args:
        office_name (str): The name of the office to plot.
    """
    # Filter data for the selected office
    office_data = monthly_spending_by_office[monthly_spending_by_office['ofic_solicitante_'] == office_name].copy()

    # Create a matplotlib figure and axes
    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Create the time series plot using seaborn for the specific office
    sb.lineplot(data=office_data, x='month_year', y='importe_por_item_may25', ax=ax, label=office_name) # Add label for the office line


    # Add the line for the overall average monthly spending
    sb.lineplot(
        data=overall_monthly_average_spending,
        x='month_year',
        y='importe_por_item_may25',
        ax=ax,
        color='red', # Make the average line stand out
        linestyle='--', # Use a dashed line for the average
        label='Promedio General' # Label for the average line
    )

    # Set plot title and labels
    ax.set_title(f'Gasto Mensual para {office_name} vs Promedio General (Ajustado a Precios Mayo 2025)') # Updated title
    ax.set_xlabel('Mes')
    ax.set_ylabel('Gasto Mensual (Millones de ARS)')

    # Format y-axis labels to show millions with dollar sign
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x/1000000:.2f}M'))

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Add a legend
    ax.legend(title='Serie de Gasto') # Add a legend to differentiate the lines

    # Ensure layout is tight to prevent labels overlapping
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Modified the plot_office_spending function to include the overall average monthly spending.")
# Out:
# Modified the plot_office_spending function to include the overall average monthly spending.

# %%
# Calculate the overall average monthly spending across all offices
overall_monthly_average_spending = monthly_spending_by_office.groupby('month_year')['importe_por_item_may25'].mean().reset_index()

print("Overall average monthly spending across all offices:")
display(overall_monthly_average_spending.head())

print("\nInformation about the overall average monthly spending dataframe:")
overall_monthly_average_spending.info()
# Out:
# Overall average monthly spending across all offices:
#   month_year  importe_por_item_may25
# 0 2024-01-01            2.315694e+08
# 1 2024-02-01            2.025758e+08
# 2 2024-03-01            1.768313e+08
# 3 2024-04-01            1.984127e+08
# 4 2024-05-01            2.261349e+08
# Information about the overall average monthly spending dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   month_year              20 non-null     datetime64[ns]
#  1   importe_por_item_may25  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 452.0 bytes

# %%
# Calculate the total adjusted spending by office and letra_fondo_
spending_by_office_and_fondo = processed_df_filtered_programas.groupby(['ofic_solicitante_', 'letra_fondo_'])['importe_por_item_may25'].sum().reset_index()

# Convert spending to millions of ARS
spending_by_office_and_fondo['importe_por_item_may25_millions'] = spending_by_office_and_fondo['importe_por_item_may25'] / 1_000_000

print("Total adjusted spending by office and 'letra_fondo_' (in millions of ARS):")
display(spending_by_office_and_fondo[['ofic_solicitante_', 'letra_fondo_', 'importe_por_item_may25_millions']].head().style.format({'importe_por_item_may25_millions': '${:.2f}M'}))

print("\nInformation about the spending by office and 'letra_fondo_' dataframe:")
spending_by_office_and_fondo.info()
# Out:
# Total adjusted spending by office and 'letra_fondo_' (in millions of ARS):
# <style type="text/css">
# </style>
# <table id="T_b36ff" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b36ff_level0_col0" class="col_heading level0 col0" >ofic_solicitante_</th>
#       <th id="T_b36ff_level0_col1" class="col_heading level0 col1" >letra_fondo_</th>
#       <th id="T_b36ff_level0_col2" class="col_heading level0 col2" >importe_por_item_may25_millions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b36ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b36ff_row0_col0" class="data row0 col0" >CASA DEL JOVEN</td>
#       <td id="T_b36ff_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_b36ff_row0_col2" class="data row0 col2" >$6.85M</td>
#     </tr>
#     <tr>
#       <th id="T_b36ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b36ff_row1_col0" class="data row1 col0" >CRSL</td>
#       <td id="T_b36ff_row1_col1" class="data row1 col1" >A</td>
#       <td id="T_b36ff_row1_col2" class="data row1 col2" >$0.22M</td>
#     </tr>
#     <tr>
#       <th id="T_b36ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b36ff_row2_col0" class="data row2 col0" >CÓRDOBA</td>
#       <td id="T_b36ff_row2_col1" class="data row2 col1" >A</td>
#       <td id="T_b36ff_row2_col2" class="data row2 col2" >$631.00M</td>
#     </tr>
#     <tr>
#       <th id="T_b36ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b36ff_row3_col0" class="data row3 col0" >CÓRDOBA</td>
#       <td id="T_b36ff_row3_col1" class="data row3 col1" >N</td>
#       <td id="T_b36ff_row3_col2" class="data row3 col2" >$220.31M</td>
#     </tr>
#     <tr>
#       <th id="T_b36ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b36ff_row4_col0" class="data row4 col0" >CÓRDOBA</td>
#       <td id="T_b36ff_row4_col1" class="data row4 col1" >R</td>
#       <td id="T_b36ff_row4_col2" class="data row4 col2" >$122.97M</td>
#     </tr>
#   </tbody>
# </table>
# Information about the spending by office and 'letra_fondo_' dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ofic_solicitante_                123 non-null    object
#  1   letra_fondo_                     123 non-null    object
#  2   importe_por_item_may25           123 non-null    float64
#  3   importe_por_item_may25_millions  123 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 4.0+ KB

# %%
spending_fondo_a = spending_by_office_and_fondo[spending_by_office_and_fondo['letra_fondo_'] == 'A'].copy()
spending_fondo_r = spending_by_office_and_fondo[spending_by_office_and_fondo['letra_fondo_'] == 'R'].copy()
spending_fondo_n = spending_by_office_and_fondo[spending_by_office_and_fondo['letra_fondo_'] == 'N'].copy()

print("Spending for Fondo A:")
display(spending_fondo_a.head())

print("\nSpending for Fondo R:")
display(spending_fondo_r.head())

print("\nSpending for Fondo N:")
display(spending_fondo_n.head())
# Out:
# Spending for Fondo A:
#   ofic_solicitante_ letra_fondo_  importe_por_item_may25  \
# 0    CASA DEL JOVEN            A            6.852969e+06
# 1              CRSL            A            2.158099e+05
# 2           CÓRDOBA            A            6.309961e+08
# 5    ELPIDIO TORRES            A            1.906593e+08
# 8    FLORENCIO DIAZ            A            2.076663e+08
#
#    importe_por_item_may25_millions
# 0                         6.852969
# 1                         0.215810
# 2                       630.996068
# 5                       190.659326
# 8                       207.666262
# Spending for Fondo R:
#    ofic_solicitante_ letra_fondo_  importe_por_item_may25  \
# 4            CÓRDOBA            R            1.229670e+08
# 7     ELPIDIO TORRES            R            1.863747e+07
# 10    FLORENCIO DIAZ            R            1.157100e+07
# 13    H. ALTA GRACIA            R            2.502134e+07
# 16     H. BELL VILLE            R            1.010107e+08
#
#     importe_por_item_may25_millions
# 4                        122.967042
# 7                         18.637466
# 10                        11.570996
# 13                        25.021336
# 16                       101.010669
# Spending for Fondo N:
#    ofic_solicitante_ letra_fondo_  importe_por_item_may25  \
# 3            CÓRDOBA            N            2.203074e+08
# 6     ELPIDIO TORRES            N            2.847133e+07
# 9     FLORENCIO DIAZ            N            2.118988e+07
# 12    H. ALTA GRACIA            N            2.314433e+07
# 15     H. BELL VILLE            N            1.039742e+08
#
#     importe_por_item_may25_millions
# 3                        220.307357
# 6                         28.471329
# 9                         21.189885
# 12                        23.144330
# 15                       103.974246

# %% [markdown]
# **Reasoning**:
# Define the function to plot adjusted spending by fund type for a selected office.

# %%
def plot_office_fondo_spending(office_name):
    """
    Generates a bar chart of adjusted spending by fund type for a given office.

    Args:
        office_name (str): The name of the office to plot.
    """
    # Filter data for the selected office for each fund type
    office_spending_a = spending_fondo_a[spending_fondo_a['ofic_solicitante_'] == office_name]['importe_por_item_may25_millions'].sum()
    office_spending_r = spending_fondo_r[spending_fondo_r['ofic_solicitante_'] == office_name]['importe_por_item_may25_millions'].sum()
    office_spending_n = spending_fondo_n[spending_fondo_n['ofic_solicitante_'] == office_name]['importe_por_item_may25_millions'].sum()

    # Create a list of spending values and fund type labels
    spending_values = [office_spending_a, office_spending_r, office_spending_n]
    fund_labels = ['Fondo A', 'Fondo R', 'Fondo N']

    # Create a bar chart
    plt.figure(figsize=(8, 6))
    plt.bar(fund_labels, spending_values, color=['blue', 'green', 'orange'])

    # Set plot title and labels
    plt.title(f'Gasto Ajustado por Fondo para {office_name} (Millones de ARS)')
    plt.xlabel('Tipo de Fondo')
    plt.ylabel('Gasto Ajustado (Millones de ARS)')

    # Format y-axis labels to show millions with dollar sign
    plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x:.2f}M'))

    # Ensure layout is tight
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Defined the plot_office_fondo_spending function.")
# Out:
# Defined the plot_office_fondo_spending function.

# %%
# Get the unique list of office names
unique_offices = processed_df_filtered_programas['ofic_solicitante_'].unique().tolist()

# Create a dropdown widget instance
office_dropdown = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

print("Dropdown widget created.")
# Out:
# Dropdown widget created.

# %% [markdown]
# # Gasto por Fondo CCH para todo el período

# %%
from ipywidgets import interactive
from IPython.display import display

# Link the dropdown to the plotting function using interactive
interactive_dashboard = interactive(plot_office_fondo_spending, office_name=office_dropdown)

# Display the interactive dashboard
display(interactive_dashboard)
# Out:
# interactive(children=(Dropdown(description='Select Office:', options=('H. VIDAL ABAL', 'RAWSON', 'H. ALTA GRAC…

# %%
monthly_spending_by_office = processed_df_filtered_programas.groupby(['ofic_solicitante_', 'month_year'])['importe_por_item_may25'].sum().reset_index()

print("Monthly spending by office:")
display(monthly_spending_by_office.head())

print("\nInformation about the monthly spending dataframe:")
monthly_spending_by_office.info()
# Out:
# Monthly spending by office:
#   ofic_solicitante_ month_year  importe_por_item_may25
# 0    CASA DEL JOVEN 2024-01-01            17079.925000
# 1    CASA DEL JOVEN 2024-02-01            24676.537500
# 2    CASA DEL JOVEN 2024-03-01           773000.510650
# 3    CASA DEL JOVEN 2024-04-01           278983.462296
# 4    CASA DEL JOVEN 2024-05-01           477076.499178
# Information about the monthly spending dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       833 non-null    object
#  1   month_year              833 non-null    datetime64[ns]
#  2   importe_por_item_may25  833 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 19.7+ KB

# %%
def plot_monthly_spending(office_name):
    """
    Generates a time series plot of adjusted monthly spending for a given office.

    Args:
        office_name (str): The name of the office to plot.
    """
    # Filter data for the selected office
    office_data = monthly_spending_by_office[monthly_spending_by_office['ofic_solicitante_'] == office_name]

    # Create a matplotlib figure and axes
    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Create the time series plot using seaborn
    sb.lineplot(data=office_data, x='month_year', y='importe_por_item_may25', ax=ax)

    # Set plot title and labels
    ax.set_title(f'Gasto ajustado por ara {office_name} (Precios Mayo 2025)')
    ax.set_xlabel('Mes')
    ax.set_ylabel('Gasto ajustado (Precios Mayo 2025)')
     # Format y-axis labels to show millions with dollar sign
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x/1000000:.2f}M'))



    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Ensure layout is tight to prevent labels overlapping
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Defined the plot_monthly_spending function.")
# Out:
# Defined the plot_monthly_spending function.

# %%
from ipywidgets import Dropdown

# Get the unique list of office names
unique_offices = processed_df_filtered_programas['ofic_solicitante_'].unique().tolist()

# Create a dropdown widget instance
office_dropdown = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

print("Dropdown widget created.")
# Out:
# Dropdown widget created.

# %%
from ipywidgets import interactive
from IPython.display import display

# Assuming plot_monthly_spending is already defined
interactive_plot = interactive(plot_monthly_spending, office_name=office_dropdown)

# Display the interactive dashboard
display(interactive_plot)
# Out:
# interactive(children=(Dropdown(description='Select Office:', options=('H. VIDAL ABAL', 'RAWSON', 'H. ALTA GRAC…

# %%
fondo_a_df = processed_df_filtered_programas[processed_df_filtered_programas['letra_fondo_'] == 'A'].copy()
fondo_r_df = processed_df_filtered_programas[processed_df_filtered_programas['letra_fondo_'] == 'R'].copy()
fondo_n_df = processed_df_filtered_programas[processed_df_filtered_programas['letra_fondo_'] == 'N'].copy()

print("First 5 rows of fondo_a_df:")
display(fondo_a_df.head())

print("\nFirst 5 rows of fondo_r_df:")
display(fondo_r_df.head())

print("\nFirst 5 rows of fondo_n_df:")
display(fondo_n_df.head())
# Out:
# First 5 rows of fondo_a_df:
#      referencia_ tipo_doc_respaldo_ n°_doc_respaldo_ expediente_ estado_  \
# 319  2024/000194       HOJA DE RUTA                1         NaN  PAGADO
# 424  2024/000260            FACTURA   00001-00000389         NaN  PAGADO
# 425  2024/000261            FACTURA   00004-00000448         NaN  PAGADO
# 929  2024/000660            FACTURA   00019-00086001         NaN  PAGADO
# 930  2024/000661            FACTURA   00019-00086597         NaN  PAGADO
#
#                  grupo_ programa_                  descripcion_del_bien_  \
# 319  Rentas   Generales       461                               VIATICOS
# 424  Rentas   Generales       458  SERVICIO DE CARGA O DESCARGA (FLETES)
# 425  Rentas   Generales       458                            ROLLO PAPEL
# 929  Rentas   Generales       458                                 DIESEL
# 930  Rentas   Generales       458                                 DIESEL
#
#      n°_objeto_gasto_          ofic_solicitante_  ...  letra_cch_  \
# 319           3080200              H. VIDAL ABAL  ...          31
# 424           3040100  H. SAN JOSÉ DE LA DORMIDA  ...          33
# 425           2099900  H. SAN JOSÉ DE LA DORMIDA  ...          33
# 929           2029900  H. SAN JOSÉ DE LA DORMIDA  ...          33
# 930           2029900  H. SAN JOSÉ DE LA DORMIDA  ...          33
#
#      estado_item_  fecha_comp_datetime month_year     ipc Medicamentos  \
# 319      GENERADO           2024-01-02 2024-01-01  2.0455       1.7269
# 424      GENERADO           2024-01-12 2024-01-01  2.0455       1.7269
# 425      GENERADO           2024-01-10 2024-01-01  2.0455       1.7269
# 929      GENERADO           2024-01-04 2024-01-01  2.0455       1.7269
# 930      GENERADO           2024-01-12 2024-01-01  2.0455       1.7269
#
#     Descartables relevant_ipc importe_unitario_may25 importe_por_item_may25
# 319       1.3598       2.0455            7479.166200            7479.166200
# 424       1.3598       2.0455            5931.950000          112707.050000
# 425       1.3598       2.0455           90002.000000          900020.000000
# 929       1.3598       2.0455          163498.840045          163498.840045
# 930       1.3598       2.0455          183972.208635          183972.208635
#
# [5 rows x 27 columns]
# First 5 rows of fondo_r_df:
#       referencia_ tipo_doc_respaldo_ n°_doc_respaldo_ expediente_ estado_  \
# 2448  2024/001645            FACTURA   00005-00005932         NaN  PAGADO
# 2449  2024/001646            FACTURA   00005-00005935         NaN  PAGADO
# 2451  2024/001648            FACTURA   00005-00005937         NaN  PAGADO
# 2454  2024/001650            FACTURA   00005-00005938         NaN  PAGADO
# 2455  2024/001650            FACTURA   00005-00005938         NaN  PAGADO
#
#                   grupo_ programa_       descripcion_del_bien_  \
# 2448  Cuentas Especiales       464  GAS DIOXIDO DE CARBONO CO2
# 2449  Cuentas Especiales       464          OXIGENO MEDICINAL
# 2451  Cuentas Especiales       464          OXIGENO MEDICINAL
# 2454  Cuentas Especiales       464  GAS DIOXIDO DE CARBONO CO2
# 2455  Cuentas Especiales       464          OXIGENO MEDICINAL
#
#       n°_objeto_gasto_ ofic_solicitante_  ...  letra_cch_  estado_item_  \
# 2448           2119900    H. VILLA MARÍA  ...          76      GENERADO
# 2449           2060800    H. VILLA MARÍA  ...          76      GENERADO
# 2451           2060800    H. VILLA MARÍA  ...          76      GENERADO
# 2454           2119900    H. VILLA MARÍA  ...          76      GENERADO
# 2455           2060800    H. VILLA MARÍA  ...          76      GENERADO
#
#       fecha_comp_datetime month_year     ipc Medicamentos Descartables  \
# 2448           2024-01-05 2024-01-01  2.0455       1.7269       1.3598
# 2449           2024-01-10 2024-01-01  2.0455       1.7269       1.3598
# 2451           2024-01-13 2024-01-01  2.0455       1.7269       1.3598
# 2454           2024-01-13 2024-01-01  2.0455       1.7269       1.3598
# 2455           2024-01-13 2024-01-01  2.0455       1.7269       1.3598
#
#      relevant_ipc importe_unitario_may25 importe_por_item_may25
# 2448       2.0455                1840.95                7363.80
# 2449       2.0455                3068.25                3068.25
# 2451       2.0455                5522.85               16568.55
# 2454       2.0455                1840.95                3681.90
# 2455       2.0455                3068.25                3068.25
#
# [5 rows x 27 columns]
# First 5 rows of fondo_n_df:
#       referencia_ tipo_doc_respaldo_ n°_doc_respaldo_ expediente_ estado_  \
# 248   2024/000140       HOJA DE RUTA             3499         NaN  PAGADO
# 249   2024/000142       HOJA DE RUTA             3498         NaN  PAGADO
# 273   2024/000167            FACTURA   00003-00000251         NaN  PAGADO
# 1064  2024/000723       HOJA DE RUTA             3500         NaN  PAGADO
# 1632  2024/001025            FACTURA   00002-00000328         NaN  PAGADO
#
#                   grupo_ programa_  \
# 248   Recursos Afectados       462
# 249   Recursos Afectados       462
# 273   Recursos Afectados       462
# 1064  Recursos Afectados       462
# 1632  Recursos Afectados       462
#
#                                   descripcion_del_bien_  n°_objeto_gasto_  \
# 248                                            VIATICOS           3080200
# 249                                            VIATICOS           3080200
# 273                                         INSECTICIDA           2110200
# 1064                                           VIATICOS           3080200
# 1632  SERVICIO DE INFORMATICA Y SISTEMAS COMPUTARIZADOS           3050700
#
#      ofic_solicitante_  ...  letra_cch_  estado_item_  fecha_comp_datetime  \
# 248       H. LABOULAYE  ...         104      GENERADO           2024-01-04
# 249       H. LABOULAYE  ...         104      GENERADO           2024-01-01
# 273     FLORENCIO DIAZ  ...         146      GENERADO           2024-01-04
# 1064      H. LABOULAYE  ...         104      GENERADO           2024-01-05
# 1632     H. BELL VILLE  ...         106      GENERADO           2024-01-12
#
#      month_year     ipc Medicamentos Descartables relevant_ipc  \
# 248  2024-01-01  2.0455       1.7269       1.3598       2.0455
# 249  2024-01-01  2.0455       1.7269       1.3598       2.0455
# 273  2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1064 2024-01-01  2.0455       1.7269       1.3598       2.0455
# 1632 2024-01-01  2.0455       1.7269       1.3598       2.0455
#
#      importe_unitario_may25 importe_por_item_may25
# 248               7479.1662              7479.1662
# 249               7479.1662              7479.1662
# 273               5891.0400             70692.4800
# 1064              7479.1662              7479.1662
# 1632             80797.2500             80797.2500
#
# [5 rows x 27 columns]

# %%
monthly_spending_a = fondo_a_df.groupby(['ofic_solicitante_', 'month_year', 'letra_fondo_'])['importe_por_item_may25'].sum().reset_index()
monthly_spending_r = fondo_r_df.groupby(['ofic_solicitante_', 'month_year', 'letra_fondo_'])['importe_por_item_may25'].sum().reset_index()
monthly_spending_n = fondo_n_df.groupby(['ofic_solicitante_', 'month_year', 'letra_fondo_'])['importe_por_item_may25'].sum().reset_index()

print("Monthly spending for Fondo A:")
display(monthly_spending_a.head())
print("\nInformation about monthly_spending_a:")
monthly_spending_a.info()

print("\nMonthly spending for Fondo R:")
display(monthly_spending_r.head())
print("\nInformation about monthly_spending_r:")
monthly_spending_r.info()

print("\nMonthly spending for Fondo N:")
display(monthly_spending_n.head())
print("\nInformation about monthly_spending_n:")
monthly_spending_n.info()
# Out:
# Monthly spending for Fondo A:
#   ofic_solicitante_ month_year letra_fondo_  importe_por_item_may25
# 0    CASA DEL JOVEN 2024-01-01            A            17079.925000
# 1    CASA DEL JOVEN 2024-02-01            A            24676.537500
# 2    CASA DEL JOVEN 2024-03-01            A           773000.510650
# 3    CASA DEL JOVEN 2024-04-01            A           278983.462296
# 4    CASA DEL JOVEN 2024-05-01            A           477076.499178
# Information about monthly_spending_a:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 813 entries, 0 to 812
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       813 non-null    object
#  1   month_year              813 non-null    datetime64[ns]
#  2   letra_fondo_            813 non-null    object
#  3   importe_por_item_may25  813 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 25.5+ KB
#
# Monthly spending for Fondo R:
#   ofic_solicitante_ month_year letra_fondo_  importe_por_item_may25
# 0           CÓRDOBA 2024-01-01            R            2.870147e+06
# 1           CÓRDOBA 2024-02-01            R            1.200159e+06
# 2           CÓRDOBA 2024-03-01            R            6.193646e+06
# 3           CÓRDOBA 2024-04-01            R            1.465873e+07
# 4           CÓRDOBA 2024-05-01            R            4.564113e+06
# Information about monthly_spending_r:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703 entries, 0 to 702
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       703 non-null    object
#  1   month_year              703 non-null    datetime64[ns]
#  2   letra_fondo_            703 non-null    object
#  3   importe_por_item_may25  703 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 22.1+ KB
#
# Monthly spending for Fondo N:
#   ofic_solicitante_ month_year letra_fondo_  importe_por_item_may25
# 0           CÓRDOBA 2024-01-01            N            9.173896e+06
# 1           CÓRDOBA 2024-02-01            N            5.813788e+06
# 2           CÓRDOBA 2024-03-01            N            1.350751e+07
# 3           CÓRDOBA 2024-04-01            N            1.281335e+07
# 4           CÓRDOBA 2024-05-01            N            7.642644e+06
# Information about monthly_spending_n:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       671 non-null    object
#  1   month_year              671 non-null    datetime64[ns]
#  2   letra_fondo_            671 non-null    object
#  3   importe_por_item_may25  671 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 21.1+ KB

# %%
def plot_monthly_spending_by_fondo(office_name, fund_df):
    """
    Generates a time series plot of adjusted monthly spending for a given office
    and fund type.

    Args:
        office_name (str): The name of the office to plot.
        fund_df (pd.DataFrame): The dataframe containing spending data for a specific fund type.
    """
    # Filter data for the selected office
    office_data = fund_df[fund_df['ofic_solicitante_'] == office_name].copy()

    # Create a matplotlib figure and axes
    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Create the time series plot using seaborn
    sb.lineplot(data=office_data, x='month_year', y='importe_por_item_may25', ax=ax)

    # Determine the fund type from the dataframe name (assuming variable names match the fund type)
    fund_type = "Unknown Fund"
    if "monthly_spending_a" in globals() and fund_df is monthly_spending_a:
        fund_type = "Fondo A"
    elif "monthly_spending_r" in globals() and fund_df is monthly_spending_r:
        fund_type = "Fondo R"
    elif "monthly_spending_n" in globals() and fund_df is monthly_spending_n:
        fund_type = "Fondo N"


    # Set plot title and labels
    ax.set_title(f'Adjusted Monthly Spending for {office_name} - {fund_type} (May 2025 Prices)')
    ax.set_xlabel('Month')
    ax.set_ylabel('Adjusted Spending (May 2025 Prices)')

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Ensure layout is tight to prevent labels overlapping
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Defined the plot_monthly_spending_by_fondo function.")
# Out:
# Defined the plot_monthly_spending_by_fondo function.

# %%
from ipywidgets import Dropdown, VBox

# Get the unique list of office names from any of the monthly spending dataframes
unique_offices = monthly_spending_a['ofic_solicitante_'].unique().tolist()

# Create a dropdown widget instance for offices
office_dropdown = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

# Create a dropdown widget instance for fund types
fund_dropdown = Dropdown(
    options=['Fondo A', 'Fondo R', 'Fondo N'],
    description='Select Fund Type:',
    disabled=False,
)

print("Dropdown widgets for office and fund type created.")
# Out:
# Dropdown widgets for office and fund type created.

# %%
overall_monthly_average_a = monthly_spending_a.groupby('month_year')['importe_por_item_may25'].mean().reset_index()
overall_monthly_average_r = monthly_spending_r.groupby('month_year')['importe_por_item_may25'].mean().reset_index()
overall_monthly_average_n = monthly_spending_n.groupby('month_year')['importe_por_item_may25'].mean().reset_index()

print("Overall average monthly spending for Fondo A:")
display(overall_monthly_average_a.head())

print("\nOverall average monthly spending for Fondo R:")
display(overall_monthly_average_r.head())

print("\nOverall average monthly spending for Fondo N:")
display(overall_monthly_average_n.head())
# Out:
# Overall average monthly spending for Fondo A:
#   month_year  importe_por_item_may25
# 0 2024-01-01            3.980577e+06
# 1 2024-02-01            6.112302e+06
# 2 2024-03-01            9.915693e+06
# 3 2024-04-01            1.229445e+07
# 4 2024-05-01            1.434078e+07
# Overall average monthly spending for Fondo R:
#   month_year  importe_por_item_may25
# 0 2024-01-01            1.118669e+06
# 1 2024-02-01            8.873491e+05
# 2 2024-03-01            1.696157e+06
# 3 2024-04-01            1.407043e+06
# 4 2024-05-01            2.065773e+06
# Overall average monthly spending for Fondo N:
#   month_year  importe_por_item_may25
# 0 2024-01-01            2.855465e+06
# 1 2024-02-01            2.733271e+06
# 2 2024-03-01            3.191237e+06
# 3 2024-04-01            3.395447e+06
# 4 2024-05-01            3.328865e+06

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

def plot_monthly_spending_by_fondo(office_name, fund_type):
    """
    Generates a time series plot of adjusted monthly spending for a given office
    and fund type, including a line for the overall average monthly spending
    across all offices for that fund type.

    Args:
        office_name (str): The name of the office to plot.
        fund_type (str): The fund type ('Fondo A', 'Fondo R', 'Fondo N').
    """
    # Select the appropriate monthly spending dataframe based on fund type
    if fund_type == 'Fondo A':
        monthly_spending_data = monthly_spending_a
        overall_average_data = overall_monthly_average_a
    elif fund_type == 'Fondo R':
        monthly_spending_data = monthly_spending_r
        overall_average_data = overall_monthly_average_r
    elif fund_type == 'Fondo N':
        monthly_spending_data = monthly_spending_n
        overall_average_data = overall_monthly_average_n
    else:
        print("Invalid fund type selected.")
        return

    # Filter data for the selected office
    office_data = monthly_spending_data[monthly_spending_data['ofic_solicitante_'] == office_name].copy()

    # Check if office_data is empty
    if office_data.empty:
        print(f"No data available for {office_name} with {fund_type}.")
        return

    # Create a matplotlib figure and axes
    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Create the time series plot using seaborn for the specific office
    sb.lineplot(data=office_data, x='month_year', y='importe_por_item_may25', ax=ax, label=office_name)

    # Add the line for the overall average monthly spending for the selected fund type
    sb.lineplot(
        data=overall_average_data,
        x='month_year',
        y='importe_por_item_may25',
        ax=ax,
        color='red', # Make the average line stand out
        linestyle='--', # Use a dashed line for the average
        label=f'Promedio General ({fund_type})' # Label for the average line
    )

    # Set plot title and labels
    ax.set_title(f'Gasto Mensual para {office_name} vs Promedio General ({fund_type}) (Ajustado a Precios Mayo 2025)')
    ax.set_xlabel('Mes')
    ax.set_ylabel('Gasto Mensual (Millones de ARS)')

    # Format y-axis labels to show millions with dollar sign
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x/1000000:.2f}M'))


    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Add a legend
    ax.legend(title='Serie de Gasto') # Add a legend to differentiate the lines

    # Ensure layout is tight to prevent labels overlapping
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Modified the plot_monthly_spending_by_fondo function to include a check for empty data.")
# Out:
# Modified the plot_monthly_spending_by_fondo function to include a check for empty data.

# %% [markdown]
# # Evolución del gasto por Fondo CCH vs promedio

# %%
from ipywidgets import interactive
from IPython.display import display

# Assuming office_dropdown and fund_dropdown are already defined and available
# Assuming plot_monthly_spending_by_fondo is already defined

# Link the dropdowns to the plotting function using interactive
interactive_dashboard_time_series = interactive(plot_monthly_spending_by_fondo, office_name=office_dropdown, fund_type=fund_dropdown)

# Display the interactive dashboard
display(interactive_dashboard_time_series)

print("Interactive time series dashboard by fund type linked and displayed.")
# Out:
# interactive(children=(Dropdown(description='Select Office:', options=('CASA DEL JOVEN', 'CRSL', 'CÓRDOBA', 'EL…
# Interactive time series dashboard by fund type linked and displayed.

# %%
total_spending_by_office_and_fondo = processed_df_filtered_programas.groupby(['ofic_solicitante_', 'letra_fondo_'])['importe_por_item_may25'].sum().reset_index()

print("Total adjusted spending by office and fund type:")
display(total_spending_by_office_and_fondo.head())

print("\nInformation about the total spending by office and fund type dataframe:")
total_spending_by_office_and_fondo.info()
# Out:
# Total adjusted spending by office and fund type:
#   ofic_solicitante_ letra_fondo_  importe_por_item_may25
# 0    CASA DEL JOVEN            A            6.852969e+06
# 1              CRSL            A            2.158099e+05
# 2           CÓRDOBA            A            6.309961e+08
# 3           CÓRDOBA            N            2.203074e+08
# 4           CÓRDOBA            R            1.229670e+08
# Information about the total spending by office and fund type dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       123 non-null    object
#  1   letra_fondo_            123 non-null    object
#  2   importe_por_item_may25  123 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.0+ KB

# %%
total_spending_by_office = processed_df_filtered_programas.groupby('ofic_solicitante_')['importe_por_item_may25'].sum().reset_index()

print("Total adjusted spending by office:")
display(total_spending_by_office.head())

print("\nInformation about the total spending by office dataframe:")
total_spending_by_office.info()
# Out:
# Total adjusted spending by office:
#   ofic_solicitante_  importe_por_item_may25
# 0    CASA DEL JOVEN            1.903134e+07
# 1              CRSL            2.158099e+05
# 2           CÓRDOBA            1.399841e+10
# 3    ELPIDIO TORRES            2.056043e+09
# 4    FLORENCIO DIAZ            1.105394e+09
# Information about the total spending by office dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       43 non-null     object
#  1   importe_por_item_may25  43 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 820.0+ bytes

# %%
spending_by_office_and_fondo_percentage = pd.merge(
    total_spending_by_office_and_fondo,
    total_spending_by_office,
    on='ofic_solicitante_',
    suffixes=('_fondo', '_total')
)

spending_by_office_and_fondo_percentage['percentage'] = (
    spending_by_office_and_fondo_percentage['importe_por_item_may25_fondo'] /
    spending_by_office_and_fondo_percentage['importe_por_item_may25_total']
) * 100

print("Percentage of adjusted spending by office and fund type:")
display(spending_by_office_and_fondo_percentage.head())

print("\nInformation about the percentage spending dataframe:")
spending_by_office_and_fondo_percentage.info()
# Out:
# Percentage of adjusted spending by office and fund type:
#   ofic_solicitante_ letra_fondo_  importe_por_item_may25_fondo  \
# 0    CASA DEL JOVEN            A                  6.852969e+06
# 1              CRSL            A                  2.158099e+05
# 2           CÓRDOBA            A                  6.309961e+08
# 3           CÓRDOBA            N                  2.203074e+08
# 4           CÓRDOBA            R                  1.229670e+08
#
#    importe_por_item_may25_total  percentage
# 0                  1.903134e+07   36.008869
# 1                  2.158099e+05  100.000000
# 2                  1.399841e+10    4.507626
# 3                  1.399841e+10    1.573803
# 4                  1.399841e+10    0.878436
# Information about the percentage spending dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ofic_solicitante_             123 non-null    object
#  1   letra_fondo_                  123 non-null    object
#  2   importe_por_item_may25_fondo  123 non-null    float64
#  3   importe_por_item_may25_total  123 non-null    float64
#  4   percentage                    123 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 4.9+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

def plot_office_fondo_percentage(office_name):
    """
    Generates a bar chart showing the percentage of adjusted spending by fund type
    for a given office, with a point for the overall average percentage for each fund type.

    Args:
        office_name (str): The name of the office to plot.
    """
    # Filter data for the selected office
    office_data = spending_by_office_and_fondo_percentage[
        spending_by_office_and_fondo_percentage['ofic_solicitante_'] == office_name
    ].copy()

    # Create a matplotlib figure and axes
    plt.figure(figsize=(10, 6))
    ax = plt.gca()

    # Create the bar chart using seaborn
    sb.barplot(
        data=office_data,
        x='letra_fondo_',
        y='percentage',
        ax=ax,
        palette='viridis' # Use a different color palette
    )

    # Add a point for the overall average percentage for each fund type
    # Assuming overall_fund_type_percentages is available from a previous step
    if 'overall_fund_type_percentages' in globals():
        # Calculate the mean percentage for each fund type across all offices
        overall_mean_percentages = spending_by_office_and_fondo_percentage.groupby('letra_fondo_')['percentage'].mean().reset_index()

        # Ensure the fund types in overall_mean_percentages match the x-axis order
        overall_mean_percentages_sorted = overall_mean_percentages.set_index('letra_fondo_').loc[office_data['letra_fondo_']].reset_index()


        sb.scatterplot(
            data=overall_mean_percentages_sorted,
            x='letra_fondo_',
            y='percentage',
            ax=ax,
            color='red', # Make the average point stand out
            marker='X',  # Use a distinct marker
            s=100, # Increase marker size
            label='Promedio General'
        )
    else:
        print("Error: 'spending_by_office_and_fondo_percentage' DataFrame not found.")


    # Set plot title and labels
    ax.set_title(f'Composición del Gasto por Fondo para {office_name} vs Promedio General')
    ax.set_xlabel('Fondo')
    ax.set_ylabel('Porcentaje del Gasto Total del Hospital')

    # Format y-axis labels to show percentages
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.1f}%'))

    # Add a legend
    ax.legend(title='Serie de Gasto')


    # Ensure layout is tight
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Modified the plot_office_fondo_percentage function to include a point for the overall average percentage.")
# Out:
# Modified the plot_office_fondo_percentage function to include a point for the overall average percentage.

# %%
from ipywidgets import Dropdown

# Get the unique list of office names
unique_offices = spending_by_office_and_fondo_percentage['ofic_solicitante_'].unique().tolist()

# Create a dropdown widget instance
office_dropdown = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

print("Dropdown widget created for selecting offices.")
# Out:
# Dropdown widget created for selecting offices.

# %% [markdown]
# # Porcentaje del gasto total por Fondo CCH

# %%
from ipywidgets import interactive
from IPython.display import display

# Assuming office_dropdown and plot_office_fondo_percentage are already defined and available

# Link the dropdown to the plotting function using interactive
interactive_dashboard_percentage = interactive(plot_office_fondo_percentage, office_name=office_dropdown)

# Display the interactive dashboard
display(interactive_dashboard_percentage)

print("Interactive dashboard showing percentage of spending by fund type linked and displayed.")
# Out:
# interactive(children=(Dropdown(description='Select Office:', index=2, options=('CASA DEL JOVEN', 'CRSL', 'CÓRD…
# Interactive dashboard showing percentage of spending by fund type linked and displayed.

# %%
monthly_spending_by_fund_type = processed_df_filtered_programas.groupby(['month_year', 'letra_fondo_'])['importe_por_item_may25'].sum().reset_index()

print("Monthly spending by fund type:")
display(monthly_spending_by_fund_type.head())

print("\nInformation about the monthly spending by fund type dataframe:")
monthly_spending_by_fund_type.info()
# Out:
# Monthly spending by fund type:
#   month_year letra_fondo_  importe_por_item_may25
# 0 2024-01-01            A            1.632037e+08
# 1 2024-01-01            N            9.708579e+07
# 2 2024-01-01            R            2.684805e+07
# 3 2024-02-01            A            2.567167e+08
# 4 2024-02-01            N            9.566448e+07
# Information about the monthly spending by fund type dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   month_year              60 non-null     datetime64[ns]
#  1   letra_fondo_            60 non-null     object
#  2   importe_por_item_may25  60 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 1.5+ KB

# %%
# Group the filtered data by month and sum the adjusted spending
total_monthly_spending = processed_df_filtered_programas.groupby('month_year')['importe_por_item_may25'].sum().reset_index()

print("Total monthly spending across all funds:")
display(total_monthly_spending.head())

print("\nInformation about the total monthly spending dataframe:")
total_monthly_spending.info()
# Out:
# Total monthly spending across all funds:
#   month_year  importe_por_item_may25
# 0 2024-01-01            9.957483e+09
# 1 2024-02-01            8.508183e+09
# 2 2024-03-01            7.426913e+09
# 3 2024-04-01            8.333332e+09
# 4 2024-05-01            9.497665e+09
# Information about the total monthly spending dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   month_year              20 non-null     datetime64[ns]
#  1   importe_por_item_may25  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 452.0 bytes

# %%
# Merge the monthly spending by fund type and total monthly spending DataFrames
merged_monthly_spending = pd.merge(
    monthly_spending_by_fund_type,
    total_monthly_spending,
    on='month_year',
    suffixes=('_fondo', '_total')
)

# Calculate the percentage of spending for each fund type relative to the total monthly spending
merged_monthly_spending['percentage_of_total'] = (
    merged_monthly_spending['importe_por_item_may25_fondo'] /
    merged_monthly_spending['importe_por_item_may25_total']
) * 100

print("Monthly percentage of spending by fund type relative to the total monthly spending:")
display(merged_monthly_spending.head())

print("\nInformation about the monthly percentage spending by fund type dataframe:")
merged_monthly_spending.info()
# Out:
# Monthly percentage of spending by fund type relative to the total monthly spending:
#   month_year letra_fondo_  importe_por_item_may25_fondo  \
# 0 2024-01-01            A                  1.632037e+08
# 1 2024-01-01            N                  9.708579e+07
# 2 2024-01-01            R                  2.684805e+07
# 3 2024-02-01            A                  2.567167e+08
# 4 2024-02-01            N                  9.566448e+07
#
#    importe_por_item_may25_total  percentage_of_total
# 0                  9.957483e+09             1.639005
# 1                  9.957483e+09             0.975003
# 2                  9.957483e+09             0.269627
# 3                  8.508183e+09             3.017292
# 4                  8.508183e+09             1.124382
# Information about the monthly percentage spending by fund type dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   month_year                    60 non-null     datetime64[ns]
#  1   letra_fondo_                  60 non-null     object
#  2   importe_por_item_may25_fondo  60 non-null     float64
#  3   importe_por_item_may25_total  60 non-null     float64
#  4   percentage_of_total           60 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 2.5+ KB

# %%
pivoted_monthly_percentage = merged_monthly_spending.pivot(
    index='month_year',
    columns='letra_fondo_',
    values='percentage_of_total'
).reset_index()

print("Pivoted monthly percentage spending by fund type:")
display(pivoted_monthly_percentage.head())

print("\nInformation about the pivoted monthly percentage spending dataframe:")
pivoted_monthly_percentage.info()
# Out:
# Pivoted monthly percentage spending by fund type:
# letra_fondo_ month_year         A         N         R
# 0            2024-01-01  1.639005  0.975003  0.269627
# 1            2024-02-01  3.017292  1.124382  0.292022
# 2            2024-03-01  5.607433  1.460931  0.890681
# 3            2024-04-01  6.196403  1.344597  0.658496
# 4            2024-05-01  6.341692  1.191676  0.804762
# Information about the pivoted monthly percentage spending dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   month_year  20 non-null     datetime64[ns]
#  1   A           20 non-null     float64
#  2   N           20 non-null     float64
#  3   R           20 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 772.0 bytes

# %%
import matplotlib.pyplot as plt
import seaborn as sb

def plot_monthly_percentage_spending():
    """
    Generates a time series plot showing the evolution of the percentage
    of spending for each fund type relative to the total spending over time.
    """
    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Plot each fund type's percentage over time
    for fund_type in ['A', 'N', 'R']:
        if fund_type in pivoted_monthly_percentage.columns:
            sb.lineplot(
                data=pivoted_monthly_percentage,
                x='month_year',
                y=fund_type,
                ax=ax,
                label=f'Fondo {fund_type}'
            )

    # Set plot title and labels
    ax.set_title('Evolución del Porcentaje del Gasto Mensual por Tipo de Fondo')
    ax.set_xlabel('Mes')
    ax.set_ylabel('Porcentaje del Gasto Total')

    # Format y-axis labels to show percentages
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.1f}%'))

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Add a legend
    ax.legend(title='Tipo de Fondo')

    # Ensure layout is tight
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Defined the plot_monthly_percentage_spending function.")
# Out:
# Defined the plot_monthly_percentage_spending function.

# %% [markdown]
#   # Evolución del gasto por Fondos durante el período

# %%
# Display the plot
plot_monthly_percentage_spending()

# %%
from ipywidgets import Dropdown

# Get the unique list of office names
unique_offices = spending_by_office_and_fondo_percentage['ofic_solicitante_'].unique().tolist()

# Create a dropdown widget instance
office_dropdown = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

print("Dropdown widget created for selecting offices.")
# Out:
# Dropdown widget created for selecting offices.

# %%
# Calculate total monthly spending by office
total_monthly_spending_by_office = processed_df_filtered_programas.groupby(['ofic_solicitante_', 'month_year'])['importe_por_item_may25'].sum().reset_index()

print("Total monthly spending by office:")
display(total_monthly_spending_by_office.head())

print("\nInformation about the total monthly spending by office dataframe:")
total_monthly_spending_by_office.info()
# Out:
# Total monthly spending by office:
#   ofic_solicitante_ month_year  importe_por_item_may25
# 0    CASA DEL JOVEN 2024-01-01            17079.925000
# 1    CASA DEL JOVEN 2024-02-01            24676.537500
# 2    CASA DEL JOVEN 2024-03-01           773000.510650
# 3    CASA DEL JOVEN 2024-04-01           278983.462296
# 4    CASA DEL JOVEN 2024-05-01           477076.499178
# Information about the total monthly spending by office dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       833 non-null    object
#  1   month_year              833 non-null    datetime64[ns]
#  2   importe_por_item_may25  833 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 19.7+ KB

# %%
# Concatenate the monthly spending dataframes for each fund type
monthly_spending_by_fondo = pd.concat([monthly_spending_a, monthly_spending_r, monthly_spending_n], ignore_index=True)

print("Combined monthly spending by office and fund type:")
display(monthly_spending_by_fondo.head())

print("\nInformation about the combined monthly spending by office and fund type dataframe:")
monthly_spending_by_fondo.info()
# Out:
# Combined monthly spending by office and fund type:
#   ofic_solicitante_ month_year letra_fondo_  importe_por_item_may25
# 0    CASA DEL JOVEN 2024-01-01            A            17079.925000
# 1    CASA DEL JOVEN 2024-02-01            A            24676.537500
# 2    CASA DEL JOVEN 2024-03-01            A           773000.510650
# 3    CASA DEL JOVEN 2024-04-01            A           278983.462296
# 4    CASA DEL JOVEN 2024-05-01            A           477076.499178
# Information about the combined monthly spending by office and fund type dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2187 entries, 0 to 2186
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       2187 non-null   object
#  1   month_year              2187 non-null   datetime64[ns]
#  2   letra_fondo_            2187 non-null   object
#  3   importe_por_item_may25  2187 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 68.5+ KB

# %%
# Merge the monthly spending by office and fund type with the total monthly spending by office
monthly_spending_percentage_by_office_and_fondo = pd.merge(
    monthly_spending_by_fondo, # Assuming monthly_spending_by_fondo is available from a previous step
    total_monthly_spending_by_office,
    on=['ofic_solicitante_', 'month_year'],
    suffixes=('_fondo', '_total')
)

# Calculate the percentage of spending for each fund type relative to the total monthly spending for the office
monthly_spending_percentage_by_office_and_fondo['percentage_of_office_total'] = (
    monthly_spending_percentage_by_office_and_fondo['importe_por_item_may25_fondo'] /
    monthly_spending_percentage_by_office_and_fondo['importe_por_item_may25_total']
) * 100

print("Monthly percentage of spending by fund type within each office's total monthly spending:")
display(monthly_spending_percentage_by_office_and_fondo.head())

print("\nInformation about the monthly percentage spending by office and fund type dataframe:")
monthly_spending_percentage_by_office_and_fondo.info()
# Out:
# Monthly percentage of spending by fund type within each office's total monthly spending:
#   ofic_solicitante_ month_year letra_fondo_  importe_por_item_may25_fondo  \
# 0    CASA DEL JOVEN 2024-01-01            A                  17079.925000
# 1    CASA DEL JOVEN 2024-02-01            A                  24676.537500
# 2    CASA DEL JOVEN 2024-03-01            A                 773000.510650
# 3    CASA DEL JOVEN 2024-04-01            A                 278983.462296
# 4    CASA DEL JOVEN 2024-05-01            A                 477076.499178
#
#    importe_por_item_may25_total  percentage_of_office_total
# 0                  17079.925000                       100.0
# 1                  24676.537500                       100.0
# 2                 773000.510650                       100.0
# 3                 278983.462296                       100.0
# 4                 477076.499178                       100.0
# Information about the monthly percentage spending by office and fund type dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2187 entries, 0 to 2186
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ofic_solicitante_             2187 non-null   object
#  1   month_year                    2187 non-null   datetime64[ns]
#  2   letra_fondo_                  2187 non-null   object
#  3   importe_por_item_may25_fondo  2187 non-null   float64
#  4   importe_por_item_may25_total  2187 non-null   float64
#  5   percentage_of_office_total    2187 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 102.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd # Import pandas

def plot_monthly_percentage_spending_by_office_with_average(office_name, fund_type):
    """
    Generates a time series plot showing the evolution of the percentage
    of spending for a specific fund type relative to the office's total monthly spending
    for a given office, and compares it to the overall average percentage for that fund type.

    Args:
        office_name (str): The name of the office to plot.
        fund_type (str): The fund type ('A', 'R', or 'N').
    """
    # Filter data for the selected office and fund type
    office_data = monthly_spending_percentage_by_office_and_fondo[
        (monthly_spending_percentage_by_office_and_fondo['ofic_solicitante_'] == office_name) &
        (monthly_spending_percentage_by_office_and_fondo['letra_fondo_'] == fund_type)
    ].copy()

    # Check if office_data is empty
    if office_data.empty:
        print(f"No data available for {office_name} with Fondo {fund_type}.")
        return

    # Drop rows with NaN values in relevant columns before plotting
    office_data.dropna(subset=['month_year', 'percentage_of_office_total', 'letra_fondo_'], inplace=True)

    # Check if office_data is empty after dropping NaNs
    if office_data.empty:
        print(f"No valid data remaining for {office_name} with Fondo {fund_type} after handling missing values.")
        return


    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Plot the percentage evolution for the specific office and fund type
    sb.lineplot(
        data=office_data,
        x='month_year',
        y='percentage_of_office_total',
        ax=ax,
        marker='o', # Add markers for clarity
        label=f'{office_name} - Fondo {fund_type}' # Update label to include fund type
    )

    # Plot the overall percentage evolution for the SELECTED fund type
    # Assuming 'pivoted_monthly_percentage' is available from a previous step
    if 'pivoted_monthly_percentage' in globals():
        if fund_type in pivoted_monthly_percentage.columns:
             sb.lineplot(
                data=pivoted_monthly_percentage,
                x='month_year',
                y=fund_type,
                ax=ax,
                color='red', # Make the average line stand out
                linestyle='--', # Use a dashed line for the average
                label=f'Promedio General Fondo {fund_type}'
            )
        else:
            print(f"Error: Fund type '{fund_type}' not found in pivoted_monthly_percentage DataFrame.")
    else:
        print("Error: 'pivoted_monthly_percentage' DataFrame not found.")


    # Set plot title and labels
    ax.set_title(f'Evolución Mensual del Porcentaje del Gasto: {office_name} - Fondo {fund_type} vs Promedio General')
    ax.set_xlabel('Mes')
    ax.set_ylabel('Porcentaje del Gasto Total del Hospital')

    # Format y-axis labels to show percentages with dollar sign
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x:.1f}%'))

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Add a legend
    ax.legend(title='Serie de Gasto')

    # Ensure layout is tight
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Modified the plot_monthly_percentage_spending_by_office_with_average function to plot only the overall percentage for the selected fund type.")
# Out:
# Modified the plot_monthly_percentage_spending_by_office_with_average function to plot only the overall percentage for the selected fund type.

# %%
print("Monthly percentage of spending by fund type within each office's total monthly spending:")
display(monthly_spending_percentage_by_office_and_fondo.head())

print("\nInformation about the monthly percentage spending by office and fund type dataframe:")
monthly_spending_percentage_by_office_and_fondo.info()
# Out:
# Monthly percentage of spending by fund type within each office's total monthly spending:
#   ofic_solicitante_ month_year letra_fondo_  importe_por_item_may25_fondo  \
# 0    CASA DEL JOVEN 2024-01-01            A                  17079.925000
# 1    CASA DEL JOVEN 2024-02-01            A                  24676.537500
# 2    CASA DEL JOVEN 2024-03-01            A                 773000.510650
# 3    CASA DEL JOVEN 2024-04-01            A                 278983.462296
# 4    CASA DEL JOVEN 2024-05-01            A                 477076.499178
#
#    importe_por_item_may25_total  percentage_of_office_total
# 0                  17079.925000                       100.0
# 1                  24676.537500                       100.0
# 2                 773000.510650                       100.0
# 3                 278983.462296                       100.0
# 4                 477076.499178                       100.0
# Information about the monthly percentage spending by office and fund type dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2187 entries, 0 to 2186
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ofic_solicitante_             2187 non-null   object
#  1   month_year                    2187 non-null   datetime64[ns]
#  2   letra_fondo_                  2187 non-null   object
#  3   importe_por_item_may25_fondo  2187 non-null   float64
#  4   importe_por_item_may25_total  2187 non-null   float64
#  5   percentage_of_office_total    2187 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 102.6+ KB

# %%
# Pivot the monthly_spending_percentage_by_office_and_fondo dataframe to have fund types as columns
monthly_spending_wide = monthly_spending_percentage_by_office_and_fondo.pivot_table(
    index=['ofic_solicitante_', 'month_year'],
    columns='letra_fondo_',
    values='importe_por_item_may25_fondo'
).reset_index()

# Rename the columns for clarity
monthly_spending_wide.columns.name = None # Remove the columns name
monthly_spending_wide = monthly_spending_wide.rename(columns={
    'A': 'Fondo A Spending',
    'R': 'Fondo R Spending',
    'N': 'Fondo N Spending'
})

print("Monthly spending by office with separate columns for each fund type:")
display(monthly_spending_wide.head())

print("\nInformation about the monthly spending wide dataframe:")
monthly_spending_wide.info()
# Out:
# Monthly spending by office with separate columns for each fund type:
#   ofic_solicitante_ month_year  Fondo A Spending  Fondo N Spending  \
# 0    CASA DEL JOVEN 2024-01-01      17079.925000               NaN
# 1    CASA DEL JOVEN 2024-02-01      24676.537500               NaN
# 2    CASA DEL JOVEN 2024-03-01     773000.510650               NaN
# 3    CASA DEL JOVEN 2024-04-01     278983.462296               NaN
# 4    CASA DEL JOVEN 2024-05-01     477076.499178               NaN
#
#    Fondo R Spending
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# Information about the monthly spending wide dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817 entries, 0 to 816
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ofic_solicitante_  817 non-null    object
#  1   month_year         817 non-null    datetime64[ns]
#  2   Fondo A Spending   813 non-null    float64
#  3   Fondo N Spending   671 non-null    float64
#  4   Fondo R Spending   703 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 32.0+ KB

# %%
print("Unique values in 'letra_fondo_' column of monthly_spending_percentage_by_office_and_fondo:")
display(monthly_spending_percentage_by_office_and_fondo['letra_fondo_'].unique())

print("\nValue counts of 'letra_fondo_' column of monthly_spending_percentage_by_office_and_fondo:")
display(monthly_spending_percentage_by_office_and_fondo['letra_fondo_'].value_counts())
# Out:
# Unique values in 'letra_fondo_' column of monthly_spending_percentage_by_office_and_fondo:
# array(['A', 'R', 'N'], dtype=object)
# Value counts of 'letra_fondo_' column of monthly_spending_percentage_by_office_and_fondo:
# letra_fondo_
# A    813
# R    703
# N    671
# Name: count, dtype: int64

# %%
print("Shape of monthly_spending_percentage_by_office_and_fondo:", monthly_spending_percentage_by_office_and_fondo.shape)
print("\nList of columns in monthly_spending_percentage_by_office_and_fondo:")
print(list(monthly_spending_percentage_by_office_and_fondo.columns))

# Try accessing the column using .get() which returns None instead of raising an error
letra_fondo_column = monthly_spending_percentage_by_office_and_fondo.get('letra_fondo_')

if letra_fondo_column is not None:
    print("\n'letra_fondo_' column successfully accessed using .get().")
    print("\nUnique values in 'letra_fondo_' column:")
    display(letra_fondo_column.unique())
    print("\nValue counts of 'letra_fondo_' column:")
    display(letra_fondo_column.value_counts())
else:
    print("\n'letra_fondo_' column could not be accessed using .get().")
# Out:
# Shape of monthly_spending_percentage_by_office_and_fondo: (2187, 6)
#
# List of columns in monthly_spending_percentage_by_office_and_fondo:
# ['ofic_solicitante_', 'month_year', 'letra_fondo_', 'importe_por_item_may25_fondo', 'importe_por_item_may25_total', 'percentage_of_office_total']
#
# 'letra_fondo_' column successfully accessed using .get().
#
# Unique values in 'letra_fondo_' column:
# array(['A', 'R', 'N'], dtype=object)
# Value counts of 'letra_fondo_' column:
# letra_fondo_
# A    813
# R    703
# N    671
# Name: count, dtype: int64

# %%
print("Columns in monthly_spending_by_fondo:")
display(monthly_spending_by_fondo.columns)

print("\nFirst 5 rows of monthly_spending_by_fondo:")
display(monthly_spending_by_fondo.head())

print("\nInformation about monthly_spending_by_fondo:")
monthly_spending_by_fondo.info()
# Out:
# Columns in monthly_spending_by_fondo:
# Index(['ofic_solicitante_', 'month_year', 'letra_fondo_',
#        'importe_por_item_may25'],
#       dtype='object')
# First 5 rows of monthly_spending_by_fondo:
#   ofic_solicitante_ month_year letra_fondo_  importe_por_item_may25
# 0    CASA DEL JOVEN 2024-01-01            A            17079.925000
# 1    CASA DEL JOVEN 2024-02-01            A            24676.537500
# 2    CASA DEL JOVEN 2024-03-01            A           773000.510650
# 3    CASA DEL JOVEN 2024-04-01            A           278983.462296
# 4    CASA DEL JOVEN 2024-05-01            A           477076.499178
# Information about monthly_spending_by_fondo:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2187 entries, 0 to 2186
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ofic_solicitante_       2187 non-null   object
#  1   month_year              2187 non-null   datetime64[ns]
#  2   letra_fondo_            2187 non-null   object
#  3   importe_por_item_may25  2187 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 68.5+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd # Import pandas

def plot_monthly_percentage_spending_by_office_with_average(office_name, fund_type):
    """
    Generates a time series plot showing the evolution of the percentage
    of spending for a specific fund type relative to the office's total monthly spending
    for a given office, and compares it to the overall average percentage for that fund type.

    Args:
        office_name (str): The name of the office to plot.
        fund_type (str): The fund type ('A', 'R', 'N').
    """
    # Filter data for the selected office and fund type
    office_data = monthly_spending_percentage_by_office_and_fondo[
        (monthly_spending_percentage_by_office_and_fondo['ofic_solicitante_'] == office_name) &
        (monthly_spending_percentage_by_office_and_fondo['letra_fondo_'] == fund_type)
    ].copy()

    # Check if office_data is empty
    if office_data.empty:
        print(f"No data available for {office_name} with Fondo {fund_type}.")
        return

    # Drop rows with NaN values in relevant columns before plotting
    office_data.dropna(subset=['month_year', 'percentage_of_office_total', 'letra_fondo_'], inplace=True)

    # Check if office_data is empty after dropping NaNs
    if office_data.empty:
        print(f"No valid data remaining for {office_name} with Fondo {fund_type} after handling missing values.")
        return


    plt.figure(figsize=(12, 6))
    ax = plt.gca()

    # Plot the percentage evolution for the specific office and fund type
    sb.lineplot(
        data=office_data,
        x='month_year',
        y='percentage_of_office_total',
        ax=ax,
        marker='o', # Add markers for clarity
        label=f'{office_name} - Fondo {fund_type}' # Update label to include fund type
    )

    # Plot the overall percentage evolution for the SELECTED fund type
    # Assuming 'pivoted_monthly_percentage' is available from a previous step
    if 'pivoted_monthly_percentage' in globals():
        if fund_type in pivoted_monthly_percentage.columns:
             sb.lineplot(
                data=pivoted_monthly_percentage,
                x='month_year',
                y=fund_type,
                ax=ax,
                color='red', # Make the average line stand out
                linestyle='--', # Use a dashed line for the average
                label=f'Promedio General Fondo {fund_type}'
            )
        else:
            print(f"Error: Fund type '{fund_type}' not found in pivoted_monthly_percentage DataFrame.")
    else:
        print("Error: 'pivoted_monthly_percentage' DataFrame not found.")


    # Set plot title and labels
    ax.set_title(f'Evolución Mensual del Porcentaje del Gasto: {office_name} - Fondo {fund_type} vs Promedio General')
    ax.set_xlabel('Mes')
    ax.set_ylabel('Porcentaje del Gasto Total del Hospital')

    # Format y-axis labels to show percentages
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.1f}%'))

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)

    # Add a legend
    ax.legend(title='Serie de Gasto')

    # Ensure layout is tight
    plt.tight_layout()

    # Display the plot
    plt.show()

print("Modified the plot_monthly_percentage_spending_by_office_with_average function to plot only the overall percentage for the selected fund type.")
# Out:
# Modified the plot_monthly_percentage_spending_by_office_with_average function to plot only the overall percentage for the selected fund type.

# %%
# 1. Calculate overall fund type spending
overall_fund_type_spending = processed_df_filtered_programas.groupby('letra_fondo_')['importe_por_item_may25'].sum().reset_index()

print("Overall adjusted spending by fund type:")
display(overall_fund_type_spending)
# Out:
# Overall adjusted spending by fund type:
#   letra_fondo_  importe_por_item_may25
# 0            A            1.005375e+10
# 1            N            2.069864e+09
# 2            R            1.680229e+09

# %%
# 2. Calculate total overall spending
total_overall_spending = processed_df_filtered_programas['importe_por_item_may25'].sum()

print(f"Total overall adjusted spending across all funds and hospitals: {total_overall_spending:.2f}")
# Out:
# Total overall adjusted spending across all funds and hospitals: 116893417308.65

# %%
# 3. Calculate overall fund type percentages
overall_fund_type_percentages = overall_fund_type_spending.copy()
overall_fund_type_percentages['percentage'] = (overall_fund_type_percentages['importe_por_item_may25'] / total_overall_spending) * 100

print("Overall percentage of spending by fund type:")
display(overall_fund_type_percentages)
# Out:
# Overall percentage of spending by fund type:
#   letra_fondo_  importe_por_item_may25  percentage
# 0            A            1.005375e+10    8.600785
# 1            N            2.069864e+09    1.770727
# 2            R            1.680229e+09    1.437402

# %%
def generate_office_fund_percentage_table(office_name):
    """
    Generates a table showing the percentage of spending by fund type for a selected office
    compared to the percentage for all other hospitals combined (within Fundos A, R, N spending),
    along with a comparison.

    Args:
        office_name (str): The name of the office to analyze.
    """
    # Filter data for the selected office and only include Fundos A, R, N
    selected_office_spending_funds = spending_by_office_and_fondo[
        (spending_by_office_and_fondo['ofic_solicitante_'] == office_name) &
        (spending_by_office_and_fondo['letra_fondo_'].isin(['A', 'R', 'N']))
    ].copy()

    # Calculate the selected office's total spending from Fundos A, R, and N
    selected_office_total_funds_spending = selected_office_spending_funds['importe_por_item_may25'].sum()

    # Calculate percentage of each fund type within the selected office's Fundos A, R, N spending
    selected_office_spending_funds['percentage_office'] = (
        selected_office_spending_funds['importe_por_item_may25'] / selected_office_total_funds_spending
    ) * 100 if selected_office_total_funds_spending > 0 else 0


    # Calculate spending for all offices except the selected one, only for Fundos A, R, N
    other_hospitals_spending_funds = spending_by_office_and_fondo[
        (spending_by_office_and_fondo['ofic_solicitante_'] != office_name) &
        (spending_by_office_and_fondo['letra_fondo_'].isin(['A', 'R', 'N']))
    ].groupby('letra_fondo_')['importe_por_item_may25'].sum().reset_index()

    # Calculate total spending for all other hospitals combined from Fundos A, R, N
    total_other_hospitals_funds_spending = other_hospitals_spending_funds['importe_por_item_may25'].sum()


    # Calculate percentages for other hospitals relative to their total Fundos A, R, N spending
    other_hospitals_spending_funds['percentage_other_hospitals'] = (
        other_hospitals_spending_funds['importe_por_item_may25'] / total_other_hospitals_funds_spending
    ) * 100 if total_other_hospitals_funds_spending > 0 else 0


    # Merge selected office data with other hospitals data
    comparison_table = pd.merge(
        selected_office_spending_funds[['letra_fondo_', 'percentage_office']],
        other_hospitals_spending_funds[['letra_fondo_', 'percentage_other_hospitals']],
        on='letra_fondo_',
        how='outer' # Use outer merge to include all fund types if one is missing in either group
    )

    # Fill NaN percentages with 0 if a fund type is missing for a hospital or other hospitals
    comparison_table['percentage_office'] = comparison_table['percentage_office'].fillna(0)
    comparison_table['percentage_other_hospitals'] = comparison_table['percentage_other_hospitals'].fillna(0)

    # Rename columns for clarity (in Spanish)
    comparison_table = comparison_table.rename(columns={
        'letra_fondo_': 'Tipo de Fondo',
        'percentage_office': f'Porcentaje {office_name}',
        'percentage_other_hospitals': 'Porcentaje Otros Hospitales'
    })

    # Add comparison column (in Spanish)
    comparison_table['Supera a Otros Hospitales'] = comparison_table[f'Porcentaje {office_name}'] > comparison_table['Porcentaje Otros Hospitales']

    # Translate boolean values to Spanish
    comparison_table['Supera a Otros Hospitales'] = comparison_table['Supera a Otros Hospitales'].map({True: 'Sí', False: 'No'})


    # Display the table with percentage formatting
    print(f"\nComparación de Porcentaje de Gasto por Fondo (solo Fondos A, R, N) para {office_name} vs Otros Hospitales:")
    display(comparison_table.style.format({
        f'Porcentaje {office_name}': '${:.2f}%',
        'Porcentaje Otros Hospitales': '${:.2f}%'
    }))

print("Modified the generate_office_fund_percentage_table function to calculate percentages relative to Fundos A, R, N spending.")
# Out:
# Modified the generate_office_fund_percentage_table function to calculate percentages relative to Fundos A, R, N spending.

# %%
from ipywidgets import Dropdown

# Get the unique list of office names
unique_offices = processed_df_filtered_programas['ofic_solicitante_'].unique().tolist()

# Create a dropdown widget instance
office_dropdown_table = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

print("Dropdown widget created for selecting offices for the table dashboard.")
# Out:
# Dropdown widget created for selecting offices for the table dashboard.

# %% [markdown]
# # Gasto por fondos CCH: composición A, R y N- Tabla comparativa

# %%
from ipywidgets import interactive
from IPython.display import display

# Assuming office_dropdown_table and generate_office_fund_percentage_table are already defined and available

# Link the dropdown to the plotting function using interactive
interactive_table_dashboard = interactive(generate_office_fund_percentage_table, office_name=office_dropdown_table)

# Display the interactive dashboard
display(interactive_table_dashboard)

print("Interactive table dashboard linked and displayed.")
# Out:
# interactive(children=(Dropdown(description='Select Office:', options=('H. VIDAL ABAL', 'RAWSON', 'H. ALTA GRAC…
# Interactive table dashboard linked and displayed.

# %%
def get_top_spending_items_by_office_and_fondo(df, fund_type, n_top_items=5):
    """
    Filters a DataFrame by fund type and returns the top spending items
    for each office within that fund.

    Args:
        df (pd.DataFrame): The input DataFrame (processed_df_filtered_programas).
        fund_type (str): The fund type ('A', 'R', or 'N').
        n_top_items (int): The number of top spending items to retrieve for each office.

    Returns:
        pd.DataFrame: A DataFrame containing the top spending items for each office
                      within the specified fund.
    """
    # Filter by fund type
    fund_df = df[df['letra_fondo_'] == fund_type].copy()

    # Group by office and description, then sum the adjusted spending and sort
    top_items = fund_df.groupby(['ofic_solicitante_', 'descripcion_del_bien_'])['importe_por_item_may25'].sum().reset_index()
    top_items_sorted = top_items.sort_values(['ofic_solicitante_', 'importe_por_item_may25'], ascending=[True, False])

    # Get the top N items for each office
    top_n_items_by_office = top_items_sorted.groupby('ofic_solicitante_').head(n_top_items).reset_index(drop=True)

    return top_n_items_by_office

# Get unique office names for the dropdown
unique_offices_for_items = processed_df_filtered_programas['ofic_solicitante_'].unique().tolist()

# Create dropdowns for office and fund type
office_dropdown_items = Dropdown(
    options=unique_offices_for_items,
    description='Select Office:',
    disabled=False,
)

fund_dropdown_items = Dropdown(
    options=['A', 'R', 'N'],
    description='Select Fund Type:',
    disabled=False,
)

# Define a function to display the table based on dropdown selections
def display_top_items_table(office_name, fund_type):
    """
    Displays the top spending items table for the selected office and fund type.
    """
    top_items_df = get_top_spending_items_by_office_and_fondo(processed_df_filtered_programas, fund_type)
    office_top_items = top_items_df[top_items_df['ofic_solicitante_'] == office_name].copy()

    print(f"\nTop Spending Items for {office_name} - Fondo {fund_type} (Adjusted to May 2025 Prices):")
    display(office_top_items.style.format({'importe_por_item_may25': '${:,.2f}'}))


# Create an interactive dashboard to display the table
interactive_top_items_table = interactive(display_top_items_table, office_name=office_dropdown_items, fund_type=fund_dropdown_items)

print("Created a function to get top spending items by office and fund type, and dropdowns for interactive display.")
# Out:
# Created a function to get top spending items by office and fund type, and dropdowns for interactive display.

# %% [markdown]
# # Top Gastos por Fondo por hospital

# %%
# Display the interactive dashboard
display(interactive_top_items_table)

print("Interactive dashboard for top spending items linked and displayed.")
# Out:
# interactive(children=(Dropdown(description='Select Office:', options=('H. VIDAL ABAL', 'RAWSON', 'H. ALTA GRAC…
# Interactive dashboard for top spending items linked and displayed.

# %%
def get_top_spending_items_by_office_fondo_and_month(df, office_name, fund_type, selected_month):
    """
    Filters a DataFrame by office, fund type, and month, and returns the top spending items.

    Args:
        df (pd.DataFrame): The input DataFrame (processed_df_filtered_programas).
        office_name (str): The name of the office to filter by.
        fund_type (str): The fund type ('A', 'R', or 'N') to filter by.
        selected_month (pd.Timestamp): The month to filter by.

    Returns:
        pd.DataFrame: A DataFrame containing the top spending items for the selected
                      office, fund type, and month.
    """
    # Filter by office, fund type, and month
    filtered_df = df[
        (df['ofic_solicitante_'] == office_name) &
        (df['letra_fondo_'] == fund_type) &
        (df['month_year'] == selected_month)
    ].copy()

    # Group by description, sum spending, and sort
    top_items = filtered_df.groupby('descripcion_del_bien_')['importe_por_item_may25'].sum().reset_index()
    top_items_sorted = top_items.sort_values('importe_por_item_may25', ascending=False)

    # Get the top 10 items
    top_10_items = top_items_sorted.head(10).reset_index(drop=True)

    return top_10_items

print("Defined the function to get top spending items by office, fund type, and month.")
# Out:
# Defined the function to get top spending items by office, fund type, and month.

# %%
from ipywidgets import Dropdown
import pandas as pd

# Get unique office names
unique_offices = processed_df_filtered_programas['ofic_solicitante_'].unique().tolist()

# Get unique months with data
unique_months = sorted(processed_df_filtered_programas['month_year'].unique().tolist())

# Create dropdowns for office, fund type, and month
office_dropdown_monthly_items = Dropdown(
    options=unique_offices,
    description='Select Office:',
    disabled=False,
)

fund_dropdown_monthly_items = Dropdown(
    options=['A', 'R', 'N'],
    description='Select Fund Type:',
    disabled=False,
)

month_dropdown_monthly_items = Dropdown(
    options=unique_months,
    description='Select Month:',
    disabled=False,
)

print("Dropdown widgets for office, fund type, and month created.")
# Out:
# Dropdown widgets for office, fund type, and month created.

# %%
from ipywidgets import interactive
from IPython.display import display
import pandas as pd # Import pandas

def display_top_monthly_items_table(office_name, fund_type, selected_month):
    """
    Displays the top spending items table for the selected office, fund type, and month.
    """
    top_items_df = get_top_spending_items_by_office_fondo_and_month(
        processed_df_filtered_programas,
        office_name,
        fund_type,
        selected_month
    )

    if top_items_df.empty:
        print(f"No spending data available for {office_name}, Fondo {fund_type} in {selected_month.strftime('%Y-%m')}.")
    else:
        print(f"\nTop 10 Spending Items for {office_name} - Fondo {fund_type} in {selected_month.strftime('%Y-%m')} (Adjusted to May 2025 Prices):")
        display(top_items_df.style.format({'importe_por_item_may25': '${:,.2f}'}))


# Create an interactive dashboard to display the table
interactive_top_monthly_items_table = interactive(
    display_top_monthly_items_table,
    office_name=office_dropdown_monthly_items,
    fund_type=fund_dropdown_monthly_items,
    selected_month=month_dropdown_monthly_items
)

print("Created a function to display the top monthly items table and an interactive dashboard.")
# Out:
# Created a function to display the top monthly items table and an interactive dashboard.

# %%
from IPython.display import display

# Display the interactive dashboard for top monthly spending items
display(interactive_top_monthly_items_table)
# Out:
# interactive(children=(Dropdown(description='Select Office:', index=6, options=('H. VIDAL ABAL', 'RAWSON', 'H. …
